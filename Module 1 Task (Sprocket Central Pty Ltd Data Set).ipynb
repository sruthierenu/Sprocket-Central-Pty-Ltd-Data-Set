# %% [markdown]
# ## Name - Sruthi E R

# %% [markdown]
# ## KPMG VIRTUAL INTERNSHIP PROJECT

# %% [markdown]
# **TASK: 1 - Data Quality Assessment**
# - Assessment of data quality and completeness in preparation for analysis.
#
# **TASK: 2 - Data Insights**
# - Targeting high value customers based on customer demographics and attributes.
#
# **TASK: 3 - Data Insights and Presentation**
# - Using Visualisations to present insights.
#
# ### Background information on task -
# **Sprocket Central Pty Ltd** , a medium size bikes & cycling accessories organisation, has approached Tony Smith (Partner) in KPMG’s Lighthouse & Innovation Team. Sprocket Central Pty Ltd is keen to learn more about KPMG’s expertise in its Analytics, Information & Modelling team.
#
# **The client provided KPMG with 4 datasets:**
#
# 1. Customer Demographic
#
# 2. Customer Addresses
#
# 3. Transactions data in the past 3 months
#
# 4. New Customer List

# %% [markdown]
# #### Objective
# 1. To, review the data quality to ensure that it is ready for our analysis. Remember to take note of any assumptions or issues we need to go back to the client on. As well as recommendations going forward to mitigate current data quality concerns.
#
# 2. Prepare a detailed approach for completing the analysis including activities   i.e. understanding the data distributions, feature engineering, data transformations, modelling, results interpretation and reporting. This detailed plan needs to be presented to the client to get a sign-off. Please advise what steps you would take.
#   - Please ensure your PowerPoint presentation includes a detailed approach for our strategy behind each of the 3 phases including activities involved in each - i.e. understanding the data distributions, feature engineering, data transformations, modelling, results interpretation and reporting. This detailed plan needs to be presented to the client to get a sign-off.
#
# 3. Please develop a dashboard that we can present to the client at our next meeting. Display your data summary and results of the analysis in a dashboard. Maximum of 3 dashboard views/tabs, creativity in layout and presentation is welcome. please find attached a client logo for incorporation.

# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Transaction sheet details

# %%
# Read the xlsx file 
transactions=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',1)
transactions.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1           2         2950  2017-02-25 00:00:00         False      Approved
# 2           3         3120  2017-05-21 00:00:00          True      Approved
# 3          37          402  2017-10-16 00:00:00         False      Approved
# 4          88         3135  2017-08-31 00:00:00         False      Approved
#
#        Unnamed: 6    Unnamed: 7     Unnamed: 8    Unnamed: 9 Unnamed: 10  \
# 0           brand  product_line  product_class  product_size  list_price
# 1           Solex      Standard         medium        medium       71.49
# 2   Trek Bicycles      Standard         medium         large     2091.47
# 3      OHM Cycles      Standard            low        medium     1793.43
# 4  Norco Bicycles      Standard         medium        medium     1198.46
#
#      Unnamed: 11              Unnamed: 12
# 0  standard_cost  product_first_sold_date
# 1          53.62                    41245
# 2         388.92                    41701
# 3         248.82                    36361
# 4          381.1                    36145

# %%
# deleting the first row
transactions=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',1,skiprows=1)
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
#dropping transaction_id column
transactions.drop('transaction_id',axis=1,inplace=True)
transactions.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost  product_first_sold_date
# 0          53.62                  41245.0
# 1         388.92                  41701.0
# 2         248.82                  36361.0
# 3         381.10                  36145.0
# 4         709.48                  42226.0

# %% [markdown]
# ### Exploring transcation datasheet

# %%
# Check the number of rows and columns in the dataframe

transactions.shape
# Out:
# (20000, 12)

# %%
# Check the column-wise info of the dataframe

transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_id               20000 non-null  int64
#  1   customer_id              20000 non-null  int64
#  2   transaction_date         20000 non-null  datetime64[ns]
#  3   online_order             19640 non-null  float64
#  4   order_status             20000 non-null  object
#  5   brand                    19803 non-null  object
#  6   product_line             19803 non-null  object
#  7   product_class            19803 non-null  object
#  8   product_size             19803 non-null  object
#  9   list_price               20000 non-null  float64
#  10  standard_cost            19803 non-null  float64
#  11  product_first_sold_date  19803 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 1.8+ MB

# %%
# Check the summary for the numeric columns 

transactions.describe()
# Out:
#         product_id   customer_id  online_order    list_price  standard_cost  \
# count  20000.00000  20000.000000  19640.000000  20000.000000   19803.000000
# mean      45.36465   1738.246050      0.500458   1107.829449     556.046951
# std       30.75359   1011.951046      0.500013    582.825242     405.955660
# min        0.00000      1.000000      0.000000     12.010000       7.210000
# 25%       18.00000    857.750000      0.000000    575.270000     215.140000
# 50%       44.00000   1736.000000      1.000000   1163.890000     507.580000
# 75%       72.00000   2613.000000      1.000000   1635.300000     795.100000
# max      100.00000   5034.000000      1.000000   2091.470000    1759.850000
#
#        product_first_sold_date
# count             19803.000000
# mean              38199.776549
# std                2875.201110
# min               33259.000000
# 25%               35667.000000
# 50%               38216.000000
# 75%               40672.000000
# max               42710.000000

# %%
#convert date columns from integer to datetime
transactions['product_first_sold_date'] = pd.to_datetime(transactions['product_first_sold_date'], unit='s')
transactions['product_first_sold_date'].head()
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [markdown]
# ### Observations
# * product_first_sold_date was not in date format,its converted to date format.
# * columns shows that transcations happended on the same  date but at different time. Thus we need to refer back the author to find out the details of the same.

# %%
# Check for the null values
transactions.isnull().sum()
# Out:
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# we can drop the null values based
transactions = transactions[-transactions["online_order"].isnull()]
transactions = transactions[-transactions["brand"].isnull()]
transactions = transactions[-transactions["product_line"].isnull()]
transactions = transactions[-transactions["product_class"].isnull()]
transactions = transactions[-transactions["product_size"].isnull()]
transactions = transactions[-transactions["standard_cost"].isnull()]
transactions = transactions[-transactions["product_first_sold_date"].isnull()]
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_id               19445 non-null  int64
#  1   customer_id              19445 non-null  int64
#  2   transaction_date         19445 non-null  datetime64[ns]
#  3   online_order             19445 non-null  float64
#  4   order_status             19445 non-null  object
#  5   brand                    19445 non-null  object
#  6   product_line             19445 non-null  object
#  7   product_class            19445 non-null  object
#  8   product_size             19445 non-null  object
#  9   list_price               19445 non-null  float64
#  10  standard_cost            19445 non-null  float64
#  11  product_first_sold_date  19445 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(2), object(5)
# memory usage: 1.9+ MB

# %%
#check for unique values
transactions.nunique()
# Out:
# product_id                  101
# customer_id                3492
# transaction_date            364
# online_order                  2
# order_status                  2
# brand                         6
# product_line                  4
# product_class                 3
# product_size                  3
# list_price                  100
# standard_cost               103
# product_first_sold_date     100
# dtype: int64

# %%
#check for duplicate values
transactions[transactions.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []

# %%
transactions["order_status"].value_counts()
# Out:
# Approved     19273
# Cancelled      172
# Name: order_status, dtype: int64

# %%
transactions["brand"].value_counts()
# Out:
# Solex             4169
# WeareA2B          3245
# Giant Bicycles    3244
# OHM Cycles        2993
# Trek Bicycles     2931
# Norco Bicycles    2863
# Name: brand, dtype: int64

# %%
transactions["product_line"].value_counts()
# Out:
# Standard    13920
# Road         3894
# Touring      1213
# Mountain      418
# Name: product_line, dtype: int64

# %%
transactions["product_class"].value_counts()
# Out:
# medium    13587
# high       2952
# low        2906
# Name: product_class, dtype: int64

# %%
transactions["product_size"].value_counts()
# Out:
# medium    12767
# large      3900
# small      2778
# Name: product_size, dtype: int64

# %%
transactions.isnull().sum()
# Out:
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
# will add "profit" column. Formulae = List price - Standard Cost
transactions["profit"] = transactions["list_price"] - transactions["standard_cost"]
transactions.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost product_first_sold_date   profit
# 0          53.62     1970-01-01 11:27:25    17.87
# 1         388.92     1970-01-01 11:35:01  1702.55
# 2         248.82     1970-01-01 10:06:01  1544.61
# 3         381.10     1970-01-01 10:02:25   817.36
# 4         709.48     1970-01-01 11:43:46  1055.82

# %% [markdown]
# ## Customer demographic sheet details

# %%
# Read the xlsx file 
customer_demographic=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',3)
customer_demographic.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3                           Unnamed: 4  \
# 0  first_name  last_name     gender  past_3_years_bike_related_purchases
# 1     Laraine  Medendorp          F                                   93
# 2         Eli    Bockman       Male                                   81
# 3       Arlin     Dearle       Male                                   61
# 4      Talbot        NaN       Male                                   33
#
#             Unnamed: 5              Unnamed: 6             Unnamed: 7  \
# 0                  DOB               job_title  job_industry_category
# 1  1953-10-12 00:00:00     Executive Secretary                 Health
# 2  1980-12-16 00:00:00  Administrative Officer     Financial Services
# 3  1954-01-20 00:00:00      Recruiting Manager               Property
# 4  1961-10-03 00:00:00                     NaN                     IT
#
#        Unnamed: 8          Unnamed: 9  \
# 0  wealth_segment  deceased_indicator
# 1   Mass Customer                   N
# 2   Mass Customer                   N
# 3   Mass Customer                   N
# 4   Mass Customer                   N
#
#                                          Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0                                            default    owns_car      tenure
# 1                                                 "'         Yes          11
# 2                       <script>alert('hi')</script>         Yes          16
# 3                                2018-02-01 00:00:00         Yes          15
# 4  () { _; } >_[$($())] { touch /tmp/blns.shellsh...          No           7

# %%
# deleting the first row
customer_demographic=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',3,skiprows=1)
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                2018-02-01 00:00:00      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0

# %%
# Check the number of rows and columns in the dataframe

customer_demographic.shape
# Out:
# (4000, 13)

# %%
# Check the column-wise info of the dataframe

customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
#  11  owns_car                             4000 non-null   object
#  12  tenure                               3913 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 406.4+ KB

# %%
# Check the summary for the numeric columns 

customer_demographic.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
# Check for the null values
customer_demographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# ### observations
# - *null values are found in DOB,job_title,job_industry_category,default,tenure*
# - *In gender female is designated in three different ways i.e F,Female,Femal and male as Male,M and there is category U.*
# - *DOB of a person is 1843, which is skewed.*
# - *Data of default cant be read.*

# %%
#percentage record missing in job_title 
506*100/4000
# Out:
# 12.65

# %%
#percentage record missing in DOB
87*100/4000
# Out:
# 2.175

# %%
#percentage record missing in job_industry_category
656*100/4000
# Out:
# 16.4

# %%
#percentage record missing in tenure
87*100/4000
# Out:
# 2.175

# %%
#DROPPING DEFAULT VALUE AS IT CANT BE READ
customer_demographic.drop('default',axis=1,inplace=True)
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# 1    Financial Services      Mass Customer                  N      Yes    16.0
# 2              Property      Mass Customer                  N      Yes    15.0
# 3                    IT      Mass Customer                  N       No     7.0
# 4                   NaN  Affluent Customer                  N      Yes     8.0

# %%
#dropping the null values as the percentage is small
customer_demographic = customer_demographic[-customer_demographic["DOB"].isnull()]
customer_demographic = customer_demographic[-customer_demographic["job_title"].isnull()]
customer_demographic = customer_demographic[-customer_demographic["job_industry_category"].isnull()]
customer_demographic = customer_demographic[-customer_demographic["tenure"].isnull()]
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2865 entries, 0 to 3996
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          2865 non-null   int64
#  1   first_name                           2865 non-null   object
#  2   last_name                            2780 non-null   object
#  3   gender                               2865 non-null   object
#  4   past_3_years_bike_related_purchases  2865 non-null   int64
#  5   DOB                                  2865 non-null   datetime64[ns]
#  6   job_title                            2865 non-null   object
#  7   job_industry_category                2865 non-null   object
#  8   wealth_segment                       2865 non-null   object
#  9   deceased_indicator                   2865 non-null   object
#  10  owns_car                             2865 non-null   object
#  11  tenure                               2865 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 291.0+ KB

# %% [markdown]
# *last_name column null value is not dropped as first_name contains sufficient information*

# %%
customer_demographic.nunique()
# Out:
# customer_id                            2865
# first_name                             2389
# last_name                              2707
# gender                                    5
# past_3_years_bike_related_purchases     100
# DOB                                    2611
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
customer_demographic['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal'], dtype=object)

# %%
#In gender female is designated in three different ways i.e F,Female,Femal,converting it to unique value

customer_demographic['gender'].replace(['Femal','F'], ['Female','Female'], inplace=True)
customer_demographic['gender'].replace(['U'], ['Undefined'], inplace=True)
customer_demographic['gender'].unique()
# Out:
# array(['Female', 'Male', 'Undefined'], dtype=object)

# %%
customer_demographic.gender.value_counts()
# Out:
# Female       1483
# Male         1381
# Undefined       1
# Name: gender, dtype: int64

# %%
#Age
customer_demographic.DOB
# Out:
# 0      1953-10-12
# 1      1980-12-16
# 2      1954-01-20
# 8      1973-03-10
# 9      1988-10-11
#           ...
# 3992   1974-12-05
# 3993   1989-04-07
# 3994   1975-12-12
# 3995   1975-08-09
# 3996   2001-07-13
# Name: DOB, Length: 2865, dtype: datetime64[ns]

# %%
customer_demographic['year'] = pd.DatetimeIndex(customer_demographic['DOB']).year
customer_demographic['month'] = pd.DatetimeIndex(customer_demographic['DOB']).month

customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure  year  month
# 0      Mass Customer                  N      Yes    11.0  1953     10
# 1      Mass Customer                  N      Yes    16.0  1980     12
# 2      Mass Customer                  N      Yes    15.0  1954      1
# 8  Affluent Customer                  N      Yes     8.0  1973      3
# 9      Mass Customer                  N      Yes    20.0  1988     10

# %%
customer_demographic['age'] = 2021- customer_demographic['year']
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure  year  month  age
# 0      Mass Customer                  N      Yes    11.0  1953     10   68
# 1      Mass Customer                  N      Yes    16.0  1980     12   41
# 2      Mass Customer                  N      Yes    15.0  1954      1   67
# 8  Affluent Customer                  N      Yes     8.0  1973      3   48
# 9      Mass Customer                  N      Yes    20.0  1988     10   33

# %%
customer_demographic[customer_demographic['age'] >= 90]
# Out:
#      customer_id first_name last_name     gender  \
# 33            34   Jephthah  Bachmann  Undefined
# 719          720     Darrel     Canet       Male
#
#      past_3_years_bike_related_purchases        DOB           job_title  \
# 33                                    59 1843-12-21     Legal Assistant
# 719                                   67 1931-10-23  Recruiting Manager
#
#     job_industry_category     wealth_segment deceased_indicator owns_car  \
# 33                     IT  Affluent Customer                  N       No
# 719                Retail  Affluent Customer                  N       No
#
#      tenure  year  month  age
# 33     20.0  1843     12  178
# 719     6.0  1931     10   90

# %% [markdown]
# *Age of customer_id - 34 is 178  which is not a correct age hence will drop this value.*

# %%
customer_demographic.drop(33, inplace = True)
customer_demographic[customer_demographic['age'] >= 90]
# Out:
#      customer_id first_name last_name gender  \
# 719          720     Darrel     Canet   Male
#
#      past_3_years_bike_related_purchases        DOB           job_title  \
# 719                                   67 1931-10-23  Recruiting Manager
#
#     job_industry_category     wealth_segment deceased_indicator owns_car  \
# 719                Retail  Affluent Customer                  N       No
#
#      tenure  year  month  age
# 719     6.0  1931     10   90

# %%
customer_demographic.gender.value_counts()
# Out:
# Female    1483
# Male      1381
# Name: gender, dtype: int64

# %%
customer_demographic.job_title.value_counts()
# Out:
# Social Worker                42
# Sales Representative         38
# Dental Hygienist             37
# Chemical Engineer            37
# Cost Accountant              36
#                              ..
# Programmer Analyst IV         2
# Research Assistant III        2
# Accounting Assistant IV       2
# Developer I                   1
# Database Administrator II     1
# Name: job_title, Length: 195, dtype: int64

# %%
customer_demographic.job_industry_category.value_counts()
# Out:
# Manufacturing         695
# Financial Services    682
# Health                543
# Retail                305
# Property              231
# IT                    126
# Entertainment         122
# Argiculture            99
# Telecommunications     61
# Name: job_industry_category, dtype: int64

# %%
customer_demographic.wealth_segment.value_counts()
# Out:
# Mass Customer        1427
# High Net Worth        734
# Affluent Customer     703
# Name: wealth_segment, dtype: int64

# %%
customer_demographic.owns_car.value_counts()
# Out:
# Yes    1463
# No     1401
# Name: owns_car, dtype: int64

# %% [markdown]
# ## Customer address sheet details

# %%
# Read the xlsx file 
customer_address=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',4)
customer_address.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  5
#
#             Unnamed: 1 Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0              address   postcode            state    country
# 1   060 Morning Avenue       2016  New South Wales  Australia
# 2  6 Meadow Vale Court       2153  New South Wales  Australia
# 3   0 Holy Cross Court       4211              QLD  Australia
# 4  17979 Del Mar Point       2448  New South Wales  Australia
#
#            Unnamed: 5
# 0  property_valuation
# 1                  10
# 2                  10
# 3                   9
# 4                   4

# %%
# deleting the first row
customer_address=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',4,skiprows=1)
customer_address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
# Check the number of rows and columns in the dataframe

customer_address.shape
# Out:
# (3999, 6)

# %%
# Check the column-wise info of the dataframe

customer_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
# Check the summary for the numeric columns 

customer_address.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
# Check for the null values
customer_address.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
customer_address.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %%
customer_address["state"].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
customer_address["state"] = customer_address["state"].replace(["NSW"],"New South Wales")
customer_address["state"] = customer_address["state"].replace(["VIC"],"Victoria")
customer_address["state"].value_counts()
# Out:
# New South Wales    2140
# Victoria           1021
# QLD                 838
# Name: state, dtype: int64

# %%
customer_address.country.value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %% [markdown]
# ## New customer list data

# %%
# Read the xlsx file 
new_customer_lists=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',2)
new_customer_lists.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# 1           1957-07-12             General Manager          Manufacturing
# 2           1970-03-22         Structural Engineer               Property
# 3  1974-08-28 00:00:00      Senior Cost Accountant     Financial Services
# 4           1979-01-28  Account Representative III          Manufacturing
#
#           Unnamed: 7          Unnamed: 8 Unnamed: 9  ... Unnamed: 13  \
# 0     wealth_segment  deceased_indicator   owns_car  ...       state
# 1      Mass Customer                   N        Yes  ...         QLD
# 2      Mass Customer                   N         No  ...         NSW
# 3  Affluent Customer                   N         No  ...         VIC
# 4  Affluent Customer                   N        Yes  ...         QLD
#
#   Unnamed: 14         Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0     country  property_valuation         NaN         NaN         NaN
# 1   Australia                   6        0.56      0.7000      0.8750
# 2   Australia                  11        0.89      0.8900      1.1125
# 3   Australia                   5        1.01      1.0100      1.0100
# 4   Australia                   1        0.87      1.0875      1.0875
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22
# 0          NaN          NaN         Rank        Value
# 1     0.743750          1.0            1      1.71875
# 2     0.945625          1.0            1      1.71875
# 3     1.010000          1.0            1      1.71875
# 4     1.087500          4.0            4      1.70312
#
# [5 rows x 23 columns]

# %%
# deleting the first row
new_customer_lists=pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',2,skiprows=1)
new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# 1      Mass Customer                  N       No  ...    NSW  Australia
# 2  Affluent Customer                  N       No  ...    VIC  Australia
# 3  Affluent Customer                  N      Yes  ...    QLD  Australia
# 4  Affluent Customer                  N       No  ...    NSW  Australia
#
#    property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                   6        0.56      0.7000       0.8750     0.743750
# 1                  11        0.89      0.8900       1.1125     0.945625
# 2                   5        1.01      1.0100       1.0100     1.010000
# 3                   1        0.87      1.0875       1.0875     1.087500
# 4                   9        0.52      0.5200       0.6500     0.650000
#
#    Unnamed: 20  Rank     Value
# 0            1     1  1.718750
# 1            1     1  1.718750
# 2            1     1  1.718750
# 3            4     4  1.703125
# 4            4     4  1.703125
#
# [5 rows x 23 columns]

# %%
# Check the number of rows and columns in the dataframe
new_customer_lists.shape
# Out:
# (1000, 23)

# %%
# Check the column-wise info of the dataframe
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Unnamed: 16                          1000 non-null   float64
#  17  Unnamed: 17                          1000 non-null   float64
#  18  Unnamed: 18                          1000 non-null   float64
#  19  Unnamed: 19                          1000 non-null   float64
#  20  Unnamed: 20                          1000 non-null   int64
#  21  Rank                                 1000 non-null   int64
#  22  Value                                1000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(11)
# memory usage: 179.8+ KB

# %%
# Check the summary for the numeric columns 

new_customer_lists.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# count         1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean             7.397000     0.747340     0.839005     0.942673     0.870514
# std              2.758804     0.205082     0.248858     0.294832     0.280891
# min              1.000000     0.400000     0.400000     0.400000     0.340000
# 25%              6.000000     0.570000     0.637500     0.712500     0.658750
# 50%              8.000000     0.750000     0.820000     0.912500     0.842625
# 75%              9.000000     0.920000     1.031875     1.142969     1.062500
# max             12.000000     1.100000     1.375000     1.718750     1.718750
#
#        Unnamed: 20         Rank        Value
# count  1000.000000  1000.000000  1000.000000
# mean    498.819000   498.819000     0.881714
# std     288.810997   288.810997     0.293525
# min       1.000000     1.000000     0.340000
# 25%     250.000000   250.000000     0.649531
# 50%     500.000000   500.000000     0.860000
# 75%     750.250000   750.250000     1.075000
# max    1000.000000  1000.000000     1.718750

# %%
new_customer_lists.nunique()
# Out:
# first_name                              940
# last_name                               961
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                     958
# job_title                               184
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        1
# owns_car                                  2
# tenure                                   23
# address                                1000
# postcode                                522
# state                                     3
# country                                   1
# property_valuation                       12
# Unnamed: 16                              71
# Unnamed: 17                             132
# Unnamed: 18                             183
# Unnamed: 19                             321
# Unnamed: 20                             324
# Rank                                    324
# Value                                   324
# dtype: int64

# %%
# Check for the null values
new_customer_lists.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
#droping unamed columns
cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Rank','Value']
new_customer_lists = new_customer_lists.drop(cols, axis=1)

# %%
new_customer_lists.gender.value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
new_customer_lists['gender'].replace(['U'], ['Undefined'], inplace=True)
new_customer_lists['gender'].unique()
# Out:
# array(['Male', 'Female', 'Undefined'], dtype=object)

# %%
new_customer_lists.DOB
# Out:
# 0     1957-07-12
# 1     1970-03-22
# 2     1974-08-28
# 3     1979-01-28
# 4     1965-09-21
#          ...
# 995   1959-10-07
# 996   2001-10-17
# 997   1954-10-05
# 998   1952-12-17
# 999   1955-10-02
# Name: DOB, Length: 1000, dtype: datetime64[ns]

# %%
new_customer_lists['year'] = pd.DatetimeIndex(new_customer_lists['DOB']).year
new_customer_lists['month'] = pd.DatetimeIndex(new_customer_lists['DOB']).month
new_customer_lists['age'] = 2021- new_customer_lists['year']

new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation    year  month   age
# 0      4500   QLD  Australia                   6  1957.0    7.0  64.0
# 1      2113   NSW  Australia                  11  1970.0    3.0  51.0
# 2      3505   VIC  Australia                   5  1974.0    8.0  47.0
# 3      4814   QLD  Australia                   1  1979.0    1.0  42.0
# 4      2093   NSW  Australia                   9  1965.0    9.0  56.0

# %%
new_customer_lists[new_customer_lists['age'] >= 90]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, year, month, age]
# Index: []

# %%
new_customer_lists["state"].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
new_customer_lists["state"] = new_customer_lists["state"].replace(["NSW"],"New South Wales")
new_customer_lists["state"] = new_customer_lists["state"].replace(["VIC"],"Victoria")
new_customer_lists["state"].value_counts()
# Out:
# New South Wales    506
# Victoria           266
# QLD                228
# Name: state, dtype: int64

# %%
#dropping the null values as the percentage is small
new_customer_lists = new_customer_lists[-new_customer_lists["DOB"].isnull()]
new_customer_lists = new_customer_lists[-new_customer_lists["job_title"].isnull()]
new_customer_lists = new_customer_lists[-new_customer_lists["job_industry_category"].isnull()]
new_customer_lists = new_customer_lists[-new_customer_lists["tenure"].isnull()]
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 735 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           735 non-null    object
#  1   last_name                            715 non-null    object
#  2   gender                               735 non-null    object
#  3   past_3_years_bike_related_purchases  735 non-null    int64
#  4   DOB                                  735 non-null    datetime64[ns]
#  5   job_title                            735 non-null    object
#  6   job_industry_category                735 non-null    object
#  7   wealth_segment                       735 non-null    object
#  8   deceased_indicator                   735 non-null    object
#  9   owns_car                             735 non-null    object
#  10  tenure                               735 non-null    int64
#  11  address                              735 non-null    object
#  12  postcode                             735 non-null    int64
#  13  state                                735 non-null    object
#  14  country                              735 non-null    object
#  15  property_valuation                   735 non-null    int64
#  16  year                                 735 non-null    float64
#  17  month                                735 non-null    float64
#  18  age                                  735 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(11)
# memory usage: 114.8+ KB

# %%
new_customer_lists["job_title"].value_counts()
# Out:
# Environmental Tech            12
# Cost Accountant               12
# Associate Professor           12
# Software Consultant           12
# Assistant Media Planner       11
#                               ..
# Software Test Engineer III     1
# Health Coach I                 1
# Office Assistant I             1
# Engineer III                   1
# Developer IV                   1
# Name: job_title, Length: 178, dtype: int64

# %%
new_customer_lists["job_industry_category"].value_counts()
# Out:
# Financial Services    187
# Manufacturing         175
# Health                138
# Retail                 73
# Property               51
# Entertainment          34
# IT                     30
# Argiculture            24
# Telecommunications     23
# Name: job_industry_category, dtype: int64

# %%
new_customer_lists["wealth_segment"].value_counts()
# Out:
# Mass Customer        369
# High Net Worth       184
# Affluent Customer    182
# Name: wealth_segment, dtype: int64

# %%
# Checking for duplicate values
new_customer_lists.duplicated().sum()
# Out:
# 0

# %%
new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode            state    country  property_valuation    year  month  \
# 0      4500              QLD  Australia                   6  1957.0    7.0
# 1      2113  New South Wales  Australia                  11  1970.0    3.0
# 2      3505         Victoria  Australia                   5  1974.0    8.0
# 3      4814              QLD  Australia                   1  1979.0    1.0
# 4      2093  New South Wales  Australia                   9  1965.0    9.0
#
#     age
# 0  64.0
# 1  51.0
# 2  47.0
# 3  42.0
# 4  56.0

# %%
new_customer_lists.shape
# Out:
# (735, 19)

# %% [markdown]
# ### Merging the data

# %%
# adding customer_id column in new_customer_lists
customer_demographic['customer_id'].iloc[-1]
# Out:
# 3997

# %%
# We need to add 'Customer Id' column to new_customer_lists for merging the tables 
new_customer_lists.insert(0,'customer_id', range(3998, 3998 + len(new_customer_lists)))

# %%
new_customer_lists.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         3998    Chickie    Brister    Male
# 1         3999      Morly     Genery    Male
# 2         4000    Ardelis  Forrester  Female
# 3         4001     Lucine      Stutt  Female
# 4         4002    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# 2    Financial Services  Affluent Customer                  N       No
# 3         Manufacturing  Affluent Customer                  N      Yes
# 4    Financial Services  Affluent Customer                  N       No
#
#    tenure              address  postcode            state    country  \
# 0      14     45 Shopko Center      4500              QLD  Australia
# 1      16    14 Mccormick Park      2113  New South Wales  Australia
# 2      10  5 Colorado Crossing      3505         Victoria  Australia
# 3       5   207 Annamark Plaza      4814              QLD  Australia
# 4      19    115 Montana Place      2093  New South Wales  Australia
#
#    property_valuation    year  month   age
# 0                   6  1957.0    7.0  64.0
# 1                  11  1970.0    3.0  51.0
# 2                   5  1974.0    8.0  47.0
# 3                   1  1979.0    1.0  42.0
# 4                   9  1965.0    9.0  56.0

# %% [markdown]
# **Merging customer_demographic and customer_address**

# %%
# Merge dataframes using the customer_id column
customer_demographic = pd.merge(customer_demographic, customer_address, how='left', on='customer_id')

# %%
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   97 1973-03-10
# 4                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 3  Business Systems Development Analyst           Argiculture
# 4               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure  year  month  age  \
# 0      Mass Customer                  N      Yes    11.0  1953     10   68
# 1      Mass Customer                  N      Yes    16.0  1980     12   41
# 2      Mass Customer                  N      Yes    15.0  1954      1   67
# 3  Affluent Customer                  N      Yes     8.0  1973      3   48
# 4      Mass Customer                  N      Yes    20.0  1988     10   33
#
#                address  postcode            state    country  \
# 0   060 Morning Avenue    2016.0  New South Wales  Australia
# 1  6 Meadow Vale Court    2153.0  New South Wales  Australia
# 2                  NaN       NaN              NaN        NaN
# 3      97736 7th Trail    2023.0  New South Wales  Australia
# 4                  NaN       NaN              NaN        NaN
#
#    property_valuation
# 0                10.0
# 1                10.0
# 2                 NaN
# 3                12.0
# 4                 NaN

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2864 entries, 0 to 2863
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          2864 non-null   int64
#  1   first_name                           2864 non-null   object
#  2   last_name                            2779 non-null   object
#  3   gender                               2864 non-null   object
#  4   past_3_years_bike_related_purchases  2864 non-null   int64
#  5   DOB                                  2864 non-null   datetime64[ns]
#  6   job_title                            2864 non-null   object
#  7   job_industry_category                2864 non-null   object
#  8   wealth_segment                       2864 non-null   object
#  9   deceased_indicator                   2864 non-null   object
#  10  owns_car                             2864 non-null   object
#  11  tenure                               2864 non-null   float64
#  12  year                                 2864 non-null   int64
#  13  month                                2864 non-null   int64
#  14  age                                  2864 non-null   int64
#  15  address                              2862 non-null   object
#  16  postcode                             2862 non-null   float64
#  17  state                                2862 non-null   object
#  18  country                              2862 non-null   object
#  19  property_valuation                   2862 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(11)
# memory usage: 469.9+ KB

# %%
customer_demographic["age_group"] = pd.cut(customer_demographic.age, [0,30,40,50,60,9999],
                                           labels=["<30","30-40","40-50","50-60","60+"])
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   97 1973-03-10
# 4                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 3  Business Systems Development Analyst           Argiculture
# 4               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator  ... tenure  year  month  age  \
# 0      Mass Customer                  N  ...   11.0  1953     10   68
# 1      Mass Customer                  N  ...   16.0  1980     12   41
# 2      Mass Customer                  N  ...   15.0  1954      1   67
# 3  Affluent Customer                  N  ...    8.0  1973      3   48
# 4      Mass Customer                  N  ...   20.0  1988     10   33
#
#                address postcode            state    country  \
# 0   060 Morning Avenue   2016.0  New South Wales  Australia
# 1  6 Meadow Vale Court   2153.0  New South Wales  Australia
# 2                  NaN      NaN              NaN        NaN
# 3      97736 7th Trail   2023.0  New South Wales  Australia
# 4                  NaN      NaN              NaN        NaN
#
#   property_valuation  age_group
# 0               10.0        60+
# 1               10.0      40-50
# 2                NaN        60+
# 3               12.0      40-50
# 4                NaN      30-40
#
# [5 rows x 21 columns]

# %%
new_customer_lists["age_group"] = pd.cut(new_customer_lists.age, [0,30,40,50,60,9999],
                                         labels=["<30","30-40","40-50","50-60","60+"])

# %%
new_customer_lists.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         3998    Chickie    Brister    Male
# 1         3999      Morly     Genery    Male
# 2         4000    Ardelis  Forrester  Female
# 3         4001     Lucine      Stutt  Female
# 4         4002    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator  ... tenure  \
# 0         Manufacturing      Mass Customer                  N  ...     14
# 1              Property      Mass Customer                  N  ...     16
# 2    Financial Services  Affluent Customer                  N  ...     10
# 3         Manufacturing  Affluent Customer                  N  ...      5
# 4    Financial Services  Affluent Customer                  N  ...     19
#
#                address postcode            state    country  \
# 0     45 Shopko Center     4500              QLD  Australia
# 1    14 Mccormick Park     2113  New South Wales  Australia
# 2  5 Colorado Crossing     3505         Victoria  Australia
# 3   207 Annamark Plaza     4814              QLD  Australia
# 4    115 Montana Place     2093  New South Wales  Australia
#
#   property_valuation    year  month   age  age_group
# 0                  6  1957.0    7.0  64.0        60+
# 1                 11  1970.0    3.0  51.0      50-60
# 2                  5  1974.0    8.0  47.0      40-50
# 3                  1  1979.0    1.0  42.0      40-50
# 4                  9  1965.0    9.0  56.0      50-60
#
# [5 rows x 21 columns]

# %%
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   97 1973-03-10
# 4                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 3  Business Systems Development Analyst           Argiculture
# 4               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator  ... tenure  year  month  age  \
# 0      Mass Customer                  N  ...   11.0  1953     10   68
# 1      Mass Customer                  N  ...   16.0  1980     12   41
# 2      Mass Customer                  N  ...   15.0  1954      1   67
# 3  Affluent Customer                  N  ...    8.0  1973      3   48
# 4      Mass Customer                  N  ...   20.0  1988     10   33
#
#                address postcode            state    country  \
# 0   060 Morning Avenue   2016.0  New South Wales  Australia
# 1  6 Meadow Vale Court   2153.0  New South Wales  Australia
# 2                  NaN      NaN              NaN        NaN
# 3      97736 7th Trail   2023.0  New South Wales  Australia
# 4                  NaN      NaN              NaN        NaN
#
#   property_valuation  age_group
# 0               10.0        60+
# 1               10.0      40-50
# 2                NaN        60+
# 3               12.0      40-50
# 4                NaN      30-40
#
# [5 rows x 21 columns]

# %%
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 735 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          735 non-null    int32
#  1   first_name                           735 non-null    object
#  2   last_name                            715 non-null    object
#  3   gender                               735 non-null    object
#  4   past_3_years_bike_related_purchases  735 non-null    int64
#  5   DOB                                  735 non-null    datetime64[ns]
#  6   job_title                            735 non-null    object
#  7   job_industry_category                735 non-null    object
#  8   wealth_segment                       735 non-null    object
#  9   deceased_indicator                   735 non-null    object
#  10  owns_car                             735 non-null    object
#  11  tenure                               735 non-null    int64
#  12  address                              735 non-null    object
#  13  postcode                             735 non-null    int64
#  14  state                                735 non-null    object
#  15  country                              735 non-null    object
#  16  property_valuation                   735 non-null    int64
#  17  year                                 735 non-null    float64
#  18  month                                735 non-null    float64
#  19  age                                  735 non-null    float64
#  20  age_group                            735 non-null    category
# dtypes: category(1), datetime64[ns](1), float64(3), int32(1), int64(4), object(11)
# memory usage: 118.6+ KB

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          2864 non-null   int64
#  1   first_name                           2864 non-null   object
#  2   last_name                            2779 non-null   object
#  3   gender                               2864 non-null   object
#  4   past_3_years_bike_related_purchases  2864 non-null   int64
#  5   DOB                                  2864 non-null   datetime64[ns]
#  6   job_title                            2864 non-null   object
#  7   job_industry_category                2864 non-null   object
#  8   wealth_segment                       2864 non-null   object
#  9   deceased_indicator                   2864 non-null   object
#  10  owns_car                             2864 non-null   object
#  11  tenure                               2864 non-null   float64
#  12  year                                 2864 non-null   int64
#  13  month                                2864 non-null   int64
#  14  age                                  2864 non-null   int64
#  15  address                              2862 non-null   object
#  16  postcode                             2862 non-null   float64
#  17  state                                2862 non-null   object
#  18  country                              2862 non-null   object
#  19  property_valuation                   2862 non-null   float64
#  20  age_group                            2864 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(3), int64(5), object(11)
# memory usage: 472.9+ KB

# %% [markdown]
# **Merging customer_demographic and new_customer_lists**

# %%
new_data = pd.concat([customer_demographic, new_customer_lists], ignore_index=True, sort=False)
new_data
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 3               9       Mala       Lind  Female
# 4              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3594         4728  Ferdinand  Romanetti    Male
# 3595         4729       Burk    Wortley    Male
# 3596         4730   Melloney      Temby  Female
# 3597         4731     Dickie    Cubbini    Male
# 3598         4732      Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      97 1973-03-10
# 4                                      49 1988-10-11
# ...                                   ...        ...
# 3594                                   60 1959-10-07
# 3595                                   22 2001-10-17
# 3596                                   17 1954-10-05
# 3597                                   30 1952-12-17
# 3598                                   56 1955-10-02
#
#                                  job_title job_industry_category  \
# 0                      Executive Secretary                Health
# 1                   Administrative Officer    Financial Services
# 2                       Recruiting Manager              Property
# 3     Business Systems Development Analyst           Argiculture
# 4                  Senior Quality Engineer    Financial Services
# ...                                    ...                   ...
# 3594                             Paralegal    Financial Services
# 3595                Senior Sales Associate                Health
# 3596          Budget/Accounting Analyst IV    Financial Services
# 3597                     Financial Advisor    Financial Services
# 3598                   Staff Accountant IV              Property
#
#          wealth_segment deceased_indicator  ... tenure    year  month   age  \
# 0         Mass Customer                  N  ...   11.0  1953.0   10.0  68.0
# 1         Mass Customer                  N  ...   16.0  1980.0   12.0  41.0
# 2         Mass Customer                  N  ...   15.0  1954.0    1.0  67.0
# 3     Affluent Customer                  N  ...    8.0  1973.0    3.0  48.0
# 4         Mass Customer                  N  ...   20.0  1988.0   10.0  33.0
# ...                 ...                ...  ...    ...     ...    ...   ...
# 3594  Affluent Customer                  N  ...    9.0  1959.0   10.0  62.0
# 3595      Mass Customer                  N  ...    6.0  2001.0   10.0  20.0
# 3596  Affluent Customer                  N  ...   15.0  1954.0   10.0  67.0
# 3597      Mass Customer                  N  ...   19.0  1952.0   12.0  69.0
# 3598      Mass Customer                  N  ...   14.0  1955.0   10.0  66.0
#
#                        address postcode            state    country  \
# 0           060 Morning Avenue   2016.0  New South Wales  Australia
# 1          6 Meadow Vale Court   2153.0  New South Wales  Australia
# 2                          NaN      NaN              NaN        NaN
# 3              97736 7th Trail   2023.0  New South Wales  Australia
# 4                          NaN      NaN              NaN        NaN
# ...                        ...      ...              ...        ...
# 3594               2 Sloan Way   2200.0  New South Wales  Australia
# 3595         04 Union Crossing   2196.0  New South Wales  Australia
# 3596  33475 Fair Oaks Junction   4702.0              QLD  Australia
# 3597        57666 Victoria Way   4215.0              QLD  Australia
# 3598        21875 Grover Drive   2010.0  New South Wales  Australia
#
#      property_valuation  age_group
# 0                  10.0        60+
# 1                  10.0      40-50
# 2                   NaN        60+
# 3                  12.0      40-50
# 4                   NaN      30-40
# ...                 ...        ...
# 3594                7.0        60+
# 3595               10.0        <30
# 3596                2.0        60+
# 3597                2.0        60+
# 3598                9.0        60+
#
# [3599 rows x 21 columns]

# %%
#We would assign the new dataframe to customer demographic where we will
#use one dataframe to capture all the customer information.
customer_demographic = new_data

customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   97 1973-03-10
# 4                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 3  Business Systems Development Analyst           Argiculture
# 4               Senior Quality Engineer    Financial Services
#
#       wealth_segment deceased_indicator  ... tenure    year  month   age  \
# 0      Mass Customer                  N  ...   11.0  1953.0   10.0  68.0
# 1      Mass Customer                  N  ...   16.0  1980.0   12.0  41.0
# 2      Mass Customer                  N  ...   15.0  1954.0    1.0  67.0
# 3  Affluent Customer                  N  ...    8.0  1973.0    3.0  48.0
# 4      Mass Customer                  N  ...   20.0  1988.0   10.0  33.0
#
#                address postcode            state    country  \
# 0   060 Morning Avenue   2016.0  New South Wales  Australia
# 1  6 Meadow Vale Court   2153.0  New South Wales  Australia
# 2                  NaN      NaN              NaN        NaN
# 3      97736 7th Trail   2023.0  New South Wales  Australia
# 4                  NaN      NaN              NaN        NaN
#
#   property_valuation  age_group
# 0               10.0        60+
# 1               10.0      40-50
# 2                NaN        60+
# 3               12.0      40-50
# 4                NaN      30-40
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Merge Transction dataframe with customer demographic dataframe to make a one single dataframe to perform analysis

# %%
transactions_exsistingcustomer = transactions
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost product_first_sold_date   profit
# 0          53.62     1970-01-01 11:27:25    17.87
# 1         388.92     1970-01-01 11:35:01  1702.55
# 2         248.82     1970-01-01 10:06:01  1544.61
# 3         381.10     1970-01-01 10:02:25   817.36
# 4         709.48     1970-01-01 11:43:46  1055.82

# %%
#For Existing Customers dataframe
transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","gender"]],
                                 on="customer_id", how="left")
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost product_first_sold_date   profit  gender
# 0          53.62     1970-01-01 11:27:25    17.87    Male
# 1         388.92     1970-01-01 11:35:01  1702.55  Female
# 2         248.82     1970-01-01 10:06:01  1544.61    Male
# 3         381.10     1970-01-01 10:02:25   817.36    Male
# 4         709.48     1970-01-01 11:43:46  1055.82     NaN

# %%
transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","past_3_years_bike_related_purchases"]],
                                 on="customer_id", how="left")

# %%
transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                customer_demographic[["customer_id","age"]],
                                on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","age_group"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","job_title"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","job_industry_category"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","wealth_segment"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","owns_car"]],
                                 on="customer_id", how="left")

# %%
transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","postcode"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","state"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","property_valuation"]],
                                 on="customer_id", how="left")

transactions_exsistingcustomer = pd.merge(transactions_exsistingcustomer,
                                 customer_demographic[["customer_id","country"]],
                                 on="customer_id", how="left")

# %%
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  ...  \
# 0           Solex     Standard        medium       medium       71.49  ...
# 1   Trek Bicycles     Standard        medium        large     2091.47  ...
# 2      OHM Cycles     Standard           low       medium     1793.43  ...
# 3  Norco Bicycles     Standard        medium       medium     1198.46  ...
# 4  Giant Bicycles     Standard        medium        large     1765.30  ...
#
#     age age_group                   job_title job_industry_category  \
# 0  66.0       60+         Software Engineer I    Financial Services
# 1  42.0     40-50         Clinical Specialist                Health
# 2  44.0     40-50  Desktop Support Technician                Retail
# 3  59.0     50-60             Staff Scientist    Financial Services
# 4   NaN       NaN                         NaN                   NaN
#
#       wealth_segment  owns_car postcode            state property_valuation  \
# 0      Mass Customer       Yes   3064.0         Victoria                6.0
# 1      Mass Customer       Yes   2196.0  New South Wales                5.0
# 2  Affluent Customer        No   2835.0  New South Wales                1.0
# 3      Mass Customer        No   2096.0  New South Wales               10.0
# 4                NaN       NaN      NaN              NaN                NaN
#
#      country
# 0  Australia
# 1  Australia
# 2  Australia
# 3  Australia
# 4        NaN
#
# [5 rows x 25 columns]

# %%
transactions_exsistingcustomer.sort_values(["transaction_date"], ascending=[False])
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 10617           0         2659       2017-12-30           0.0     Approved
# 2230           95         3216       2017-12-30           1.0     Approved
# 7328           65         3433       2017-12-30           0.0     Approved
# 1008           49          934       2017-12-30           0.0     Approved
# 15799          14         2055       2017-12-30           1.0     Approved
# ...           ...          ...              ...           ...          ...
# 15132          46         2543       2017-01-01           1.0     Approved
# 14782          87          123       2017-01-01           0.0     Approved
# 13551          94          824       2017-01-01           0.0     Approved
# 14718           3         1022       2017-01-01           1.0     Approved
# 18994          74         2804       2017-01-01           0.0     Approved
#
#                 brand product_line product_class product_size  list_price  \
# 10617           Solex     Standard        medium       medium      100.35
# 2230   Giant Bicycles     Standard        medium        large      569.56
# 7328         WeareA2B     Standard        medium       medium     1807.45
# 1008    Trek Bicycles         Road        medium       medium      533.51
# 15799           Solex     Standard          high        large     1842.92
# ...               ...          ...           ...          ...         ...
# 15132           Solex     Standard           low       medium     1289.85
# 14782      OHM Cycles     Standard        medium       medium     1636.90
# 13551  Giant Bicycles     Standard        medium        large     1635.30
# 14718   Trek Bicycles     Standard        medium        large     2091.47
# 18994        WeareA2B     Standard        medium       medium     1228.07
#
#        ...   age age_group                     job_title  \
# 10617  ...  47.0     40-50                     Professor
# 2230   ...  23.0       <30    Database Administrator III
# 7328   ...  23.0       <30   Computer Systems Analyst II
# 1008   ...  25.0       <30       Human Resources Manager
# 15799  ...  41.0     40-50  Administrative Assistant III
# ...    ...   ...       ...                           ...
# 15132  ...   NaN       NaN                           NaN
# 14782  ...  33.0     30-40            Analyst Programmer
# 13551  ...  44.0     40-50             Financial Advisor
# 14718  ...  31.0     30-40             Assistant Manager
# 18994  ...   NaN       NaN                           NaN
#
#       job_industry_category     wealth_segment  owns_car postcode  \
# 10617           Argiculture     High Net Worth       Yes   4151.0
# 2230          Manufacturing      Mass Customer       Yes   4390.0
# 7328               Property      Mass Customer        No   3174.0
# 1008          Manufacturing      Mass Customer        No   2036.0
# 15799                Retail     High Net Worth        No   2327.0
# ...                     ...                ...       ...      ...
# 15132                   NaN                NaN       NaN      NaN
# 14782    Financial Services     High Net Worth        No   2516.0
# 13551    Financial Services  Affluent Customer       Yes   4127.0
# 14718    Financial Services  Affluent Customer       Yes   2136.0
# 18994                   NaN                NaN       NaN      NaN
#
#                  state property_valuation    country
# 10617              QLD                4.0  Australia
# 2230               QLD                7.0  Australia
# 7328          Victoria                8.0  Australia
# 1008   New South Wales               12.0  Australia
# 15799  New South Wales                3.0  Australia
# ...                ...                ...        ...
# 15132              NaN                NaN        NaN
# 14782  New South Wales                8.0  Australia
# 13551              QLD                3.0  Australia
# 14718  New South Wales               10.0  Australia
# 18994              NaN                NaN        NaN
#
# [19445 rows x 25 columns]

# %% [markdown]
# Note -
# The most recent transaction happend on **2017-12-30**, which will be the comparison date.
# New Column will be created called **recency** = comaprsion date - transaction date.
# To understand since when the recent transaction happened.

# %%
transactions_exsistingcustomer['transaction_date'] = pd.to_datetime(transactions['transaction_date']).dt.date

# %%
transactions_exsistingcustomer["recency"] = 0

# %%
transactions_exsistingcustomer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19444
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   product_id                           19445 non-null  int64
#  1   customer_id                          19445 non-null  int64
#  2   transaction_date                     18899 non-null  object
#  3   online_order                         19445 non-null  float64
#  4   order_status                         19445 non-null  object
#  5   brand                                19445 non-null  object
#  6   product_line                         19445 non-null  object
#  7   product_class                        19445 non-null  object
#  8   product_size                         19445 non-null  object
#  9   list_price                           19445 non-null  float64
#  10  standard_cost                        19445 non-null  float64
#  11  product_first_sold_date              19445 non-null  datetime64[ns]
#  12  profit                               19445 non-null  float64
#  13  gender                               14066 non-null  object
#  14  past_3_years_bike_related_purchases  14066 non-null  float64
#  15  age                                  14066 non-null  float64
#  16  age_group                            14066 non-null  category
#  17  job_title                            14066 non-null  object
#  18  job_industry_category                14066 non-null  object
#  19  wealth_segment                       14066 non-null  object
#  20  owns_car                             14066 non-null  object
#  21  postcode                             14054 non-null  float64
#  22  state                                14054 non-null  object
#  23  property_valuation                   14054 non-null  float64
#  24  country                              14054 non-null  object
#  25  recency                              19445 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(8), int64(3), object(13)
# memory usage: 3.9+ MB

# %%
transactions_exsistingcustomer.isnull().sum()
# Out:
# product_id                                0
# customer_id                               0
# transaction_date                        546
# online_order                              0
# order_status                              0
# brand                                     0
# product_line                              0
# product_class                             0
# product_size                              0
# list_price                                0
# standard_cost                             0
# product_first_sold_date                   0
# profit                                    0
# gender                                 5379
# past_3_years_bike_related_purchases    5379
# age                                    5379
# age_group                              5379
# job_title                              5379
# job_industry_category                  5379
# wealth_segment                         5379
# owns_car                               5379
# postcode                               5391
# state                                  5391
# property_valuation                     5391
# country                                5391
# recency                                   0
# dtype: int64

# %%
transactions_exsistingcustomer["transaction_date"] = transactions_exsistingcustomer["transaction_date"].replace(np.nan,0,regex=True)

# %%
transactions_exsistingcustomer.isnull().sum()
# Out:
# product_id                                0
# customer_id                               0
# transaction_date                          0
# online_order                              0
# order_status                              0
# brand                                     0
# product_line                              0
# product_class                             0
# product_size                              0
# list_price                                0
# standard_cost                             0
# product_first_sold_date                   0
# profit                                    0
# gender                                 5379
# past_3_years_bike_related_purchases    5379
# age                                    5379
# age_group                              5379
# job_title                              5379
# job_industry_category                  5379
# wealth_segment                         5379
# owns_car                               5379
# postcode                               5391
# state                                  5391
# property_valuation                     5391
# country                                5391
# recency                                   0
# dtype: int64

# %%
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  ...  \
# 0           Solex     Standard        medium       medium       71.49  ...
# 1   Trek Bicycles     Standard        medium        large     2091.47  ...
# 2      OHM Cycles     Standard           low       medium     1793.43  ...
# 3  Norco Bicycles     Standard        medium       medium     1198.46  ...
# 4  Giant Bicycles     Standard        medium        large     1765.30  ...
#
#    age_group                   job_title  job_industry_category  \
# 0        60+         Software Engineer I     Financial Services
# 1      40-50         Clinical Specialist                 Health
# 2      40-50  Desktop Support Technician                 Retail
# 3      50-60             Staff Scientist     Financial Services
# 4        NaN                         NaN                    NaN
#
#       wealth_segment  owns_car  postcode            state property_valuation  \
# 0      Mass Customer       Yes    3064.0         Victoria                6.0
# 1      Mass Customer       Yes    2196.0  New South Wales                5.0
# 2  Affluent Customer        No    2835.0  New South Wales                1.0
# 3      Mass Customer        No    2096.0  New South Wales               10.0
# 4                NaN       NaN       NaN              NaN                NaN
#
#      country recency
# 0  Australia       0
# 1  Australia       0
# 2  Australia       0
# 3  Australia       0
# 4        NaN       0
#
# [5 rows x 26 columns]

# %%
transactions_exsistingcustomer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19444
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   product_id                           19445 non-null  int64
#  1   customer_id                          19445 non-null  int64
#  2   transaction_date                     19445 non-null  object
#  3   online_order                         19445 non-null  float64
#  4   order_status                         19445 non-null  object
#  5   brand                                19445 non-null  object
#  6   product_line                         19445 non-null  object
#  7   product_class                        19445 non-null  object
#  8   product_size                         19445 non-null  object
#  9   list_price                           19445 non-null  float64
#  10  standard_cost                        19445 non-null  float64
#  11  product_first_sold_date              19445 non-null  datetime64[ns]
#  12  profit                               19445 non-null  float64
#  13  gender                               14066 non-null  object
#  14  past_3_years_bike_related_purchases  14066 non-null  float64
#  15  age                                  14066 non-null  float64
#  16  age_group                            14066 non-null  category
#  17  job_title                            14066 non-null  object
#  18  job_industry_category                14066 non-null  object
#  19  wealth_segment                       14066 non-null  object
#  20  owns_car                             14066 non-null  object
#  21  postcode                             14054 non-null  float64
#  22  state                                14054 non-null  object
#  23  property_valuation                   14054 non-null  float64
#  24  country                              14054 non-null  object
#  25  recency                              19445 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(8), int64(3), object(13)
# memory usage: 3.9+ MB

# %%
transactions_exsistingcustomer
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 0               2         2950       2017-02-25           0.0     Approved
# 1               3         3120       2017-05-21           1.0     Approved
# 2              37          402       2017-10-16           0.0     Approved
# 3              88         3135       2017-08-31           0.0     Approved
# 4              78          787       2017-10-01           1.0     Approved
# ...           ...          ...              ...           ...          ...
# 19440          51         1018       2017-05-05           1.0     Approved
# 19441          41          127       2017-12-19           1.0     Approved
# 19442          87         2284       2017-05-10           1.0     Approved
# 19443           6         2764       2017-05-13           0.0     Approved
# 19444          11         1144       2017-10-28           1.0     Approved
#
#                 brand product_line product_class product_size  list_price  \
# 0               Solex     Standard        medium       medium       71.49
# 1       Trek Bicycles     Standard        medium        large     2091.47
# 2          OHM Cycles     Standard           low       medium     1793.43
# 3      Norco Bicycles     Standard        medium       medium     1198.46
# 4      Giant Bicycles     Standard        medium        large     1765.30
# ...               ...          ...           ...          ...         ...
# 19440      OHM Cycles     Standard          high       medium     2005.66
# 19441           Solex         Road        medium       medium      416.98
# 19442      OHM Cycles     Standard        medium       medium     1636.90
# 19443      OHM Cycles     Standard          high       medium      227.88
# 19444   Trek Bicycles     Standard        medium        small     1775.81
#
#        ...  age_group                   job_title  job_industry_category  \
# 0      ...        60+         Software Engineer I     Financial Services
# 1      ...      40-50         Clinical Specialist                 Health
# 2      ...      40-50  Desktop Support Technician                 Retail
# 3      ...      50-60             Staff Scientist     Financial Services
# 4      ...        NaN                         NaN                    NaN
# ...    ...        ...                         ...                    ...
# 19440  ...        <30          Help Desk Operator          Manufacturing
# 19441  ...      40-50        Compensation Analyst     Financial Services
# 19442  ...      40-50         Staff Accountant IV     Telecommunications
# 19443  ...        NaN                         NaN                    NaN
# 19444  ...        <30    Environmental Specialist                 Health
#
#           wealth_segment  owns_car  postcode            state  \
# 0          Mass Customer       Yes    3064.0         Victoria
# 1          Mass Customer       Yes    2196.0  New South Wales
# 2      Affluent Customer        No    2835.0  New South Wales
# 3          Mass Customer        No    2096.0  New South Wales
# 4                    NaN       NaN       NaN              NaN
# ...                  ...       ...       ...              ...
# 19440      Mass Customer       Yes    3109.0         Victoria
# 19441      Mass Customer        No    4405.0              QLD
# 19442     High Net Worth        No    3630.0         Victoria
# 19443                NaN       NaN       NaN              NaN
# 19444     High Net Worth       Yes    2177.0  New South Wales
#
#       property_valuation    country recency
# 0                    6.0  Australia       0
# 1                    5.0  Australia       0
# 2                    1.0  Australia       0
# 3                   10.0  Australia       0
# 4                    NaN        NaN       0
# ...                  ...        ...     ...
# 19440               10.0  Australia       0
# 19441                1.0  Australia       0
# 19442                1.0  Australia       0
# 19443                NaN        NaN       0
# 19444                9.0  Australia       0
#
# [19445 rows x 26 columns]

# %%
import datetime

comparison_date = datetime.date(2017, 12, 30)

for i in range(19445):
    if transactions_exsistingcustomer['transaction_date'][i] == 0:
        pass
    else:
        x = comparison_date - transactions_exsistingcustomer['transaction_date'][i]
        transactions_exsistingcustomer["recency"][i] = x.days

# %%
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 4          78          787       2017-10-01           1.0     Approved
#
#             brand product_line product_class product_size  list_price  ...  \
# 0           Solex     Standard        medium       medium       71.49  ...
# 1   Trek Bicycles     Standard        medium        large     2091.47  ...
# 2      OHM Cycles     Standard           low       medium     1793.43  ...
# 3  Norco Bicycles     Standard        medium       medium     1198.46  ...
# 4  Giant Bicycles     Standard        medium        large     1765.30  ...
#
#    age_group                   job_title  job_industry_category  \
# 0        60+         Software Engineer I     Financial Services
# 1      40-50         Clinical Specialist                 Health
# 2      40-50  Desktop Support Technician                 Retail
# 3      50-60             Staff Scientist     Financial Services
# 4        NaN                         NaN                    NaN
#
#       wealth_segment  owns_car  postcode            state property_valuation  \
# 0      Mass Customer       Yes    3064.0         Victoria                6.0
# 1      Mass Customer       Yes    2196.0  New South Wales                5.0
# 2  Affluent Customer        No    2835.0  New South Wales                1.0
# 3      Mass Customer        No    2096.0  New South Wales               10.0
# 4                NaN       NaN       NaN              NaN                NaN
#
#      country recency
# 0  Australia     308
# 1  Australia     223
# 2  Australia      75
# 3  Australia     121
# 4        NaN      90
#
# [5 rows x 26 columns]

# %%
transactions_exsistingcustomer.isnull().sum()
# Out:
# product_id                                0
# customer_id                               0
# transaction_date                          0
# online_order                              0
# order_status                              0
# brand                                     0
# product_line                              0
# product_class                             0
# product_size                              0
# list_price                                0
# standard_cost                             0
# product_first_sold_date                   0
# profit                                    0
# gender                                 5379
# past_3_years_bike_related_purchases    5379
# age                                    5379
# age_group                              5379
# job_title                              5379
# job_industry_category                  5379
# wealth_segment                         5379
# owns_car                               5379
# postcode                               5391
# state                                  5391
# property_valuation                     5391
# country                                5391
# recency                                   0
# dtype: int64

# %%
transactions_exsistingcustomer = transactions_exsistingcustomer[-transactions_exsistingcustomer["gender"].isnull()]
transactions_exsistingcustomer.isnull().sum()
# Out:
# product_id                              0
# customer_id                             0
# transaction_date                        0
# online_order                            0
# order_status                            0
# brand                                   0
# product_line                            0
# product_class                           0
# product_size                            0
# list_price                              0
# standard_cost                           0
# product_first_sold_date                 0
# profit                                  0
# gender                                  0
# past_3_years_bike_related_purchases     0
# age                                     0
# age_group                               0
# job_title                               0
# job_industry_category                   0
# wealth_segment                          0
# owns_car                                0
# postcode                               12
# state                                  12
# property_valuation                     12
# country                                12
# recency                                 0
# dtype: int64

# %%
transactions_exsistingcustomer = transactions_exsistingcustomer[-transactions_exsistingcustomer["postcode"].isnull()]
transactions_exsistingcustomer.isnull().sum()
# Out:
# product_id                             0
# customer_id                            0
# transaction_date                       0
# online_order                           0
# order_status                           0
# brand                                  0
# product_line                           0
# product_class                          0
# product_size                           0
# list_price                             0
# standard_cost                          0
# product_first_sold_date                0
# profit                                 0
# gender                                 0
# past_3_years_bike_related_purchases    0
# age                                    0
# age_group                              0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# postcode                               0
# state                                  0
# property_valuation                     0
# country                                0
# recency                                0
# dtype: int64

# %%
transactions_exsistingcustomer.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       2017-02-25           0.0     Approved
# 1           3         3120       2017-05-21           1.0     Approved
# 2          37          402       2017-10-16           0.0     Approved
# 3          88         3135       2017-08-31           0.0     Approved
# 5          25         2339       2017-03-08           1.0     Approved
#
#             brand product_line product_class product_size  list_price  ...  \
# 0           Solex     Standard        medium       medium       71.49  ...
# 1   Trek Bicycles     Standard        medium        large     2091.47  ...
# 2      OHM Cycles     Standard           low       medium     1793.43  ...
# 3  Norco Bicycles     Standard        medium       medium     1198.46  ...
# 5  Giant Bicycles         Road        medium       medium     1538.99  ...
#
#    age_group                   job_title  job_industry_category  \
# 0        60+         Software Engineer I     Financial Services
# 1      40-50         Clinical Specialist                 Health
# 2      40-50  Desktop Support Technician                 Retail
# 3      50-60             Staff Scientist     Financial Services
# 5        60+             Web Designer II               Property
#
#       wealth_segment  owns_car  postcode            state property_valuation  \
# 0      Mass Customer       Yes    3064.0         Victoria                6.0
# 1      Mass Customer       Yes    2196.0  New South Wales                5.0
# 2  Affluent Customer        No    2835.0  New South Wales                1.0
# 3      Mass Customer        No    2096.0  New South Wales               10.0
# 5  Affluent Customer       Yes    2153.0  New South Wales               10.0
#
#      country recency
# 0  Australia     308
# 1  Australia     223
# 2  Australia      75
# 3  Australia     121
# 5  Australia     297
#
# [5 rows x 26 columns]

# %%
transactions_exsistingcustomer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14054 entries, 0 to 19444
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   product_id                           14054 non-null  int64
#  1   customer_id                          14054 non-null  int64
#  2   transaction_date                     14054 non-null  object
#  3   online_order                         14054 non-null  float64
#  4   order_status                         14054 non-null  object
#  5   brand                                14054 non-null  object
#  6   product_line                         14054 non-null  object
#  7   product_class                        14054 non-null  object
#  8   product_size                         14054 non-null  object
#  9   list_price                           14054 non-null  float64
#  10  standard_cost                        14054 non-null  float64
#  11  product_first_sold_date              14054 non-null  datetime64[ns]
#  12  profit                               14054 non-null  float64
#  13  gender                               14054 non-null  object
#  14  past_3_years_bike_related_purchases  14054 non-null  float64
#  15  age                                  14054 non-null  float64
#  16  age_group                            14054 non-null  category
#  17  job_title                            14054 non-null  object
#  18  job_industry_category                14054 non-null  object
#  19  wealth_segment                       14054 non-null  object
#  20  owns_car                             14054 non-null  object
#  21  postcode                             14054 non-null  float64
#  22  state                                14054 non-null  object
#  23  property_valuation                   14054 non-null  float64
#  24  country                              14054 non-null  object
#  25  recency                              14054 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(8), int64(3), object(13)
# memory usage: 2.8+ MB

# %% [markdown]
# We have combined all worksheets together for proper analysis.The new datframe is called : **transactions_exsistingcustomer**.

# %% [markdown]
# ### RFM Analysis
# *RFM stands for recency, frequency and monetary value. It segments customers based on when their last purchase was, how often they've purchased in the past, and how much they've spent overall.*

# %%
transactions_exsistingcustomer.describe()
# Out:
#          product_id   customer_id  online_order    list_price  standard_cost  \
# count  14054.000000  14054.000000  14054.000000  14054.000000   14054.000000
# mean      45.613064   1718.680305      0.500356   1110.645960     559.051687
# std       30.492086   1011.286420      0.500018    584.029679     409.094565
# min        0.000000      1.000000      0.000000     12.010000       7.210000
# 25%       18.000000    831.000000      0.000000    575.270000     215.140000
# 50%       44.000000   1719.000000      1.000000   1163.890000     507.580000
# 75%       72.000000   2593.000000      1.000000   1635.300000     795.100000
# max      100.000000   3497.000000      1.000000   2091.470000    1759.850000
#
#              profit  past_3_years_bike_related_purchases           age  \
# count  14054.000000                         14054.000000  14054.000000
# mean     551.594273                            49.443290     43.706205
# std      493.376642                            28.683116     12.572443
# min        4.800000                             0.000000     19.000000
# 25%      135.850000                            25.000000     34.000000
# 50%      445.210000                            48.000000     44.000000
# 75%      827.160000                            74.000000     53.000000
# max     1702.550000                            99.000000     90.000000
#
#            postcode  property_valuation       recency
# count  14054.000000        14054.000000  14054.000000
# mean    2999.513306            7.469546    176.915967
# std      859.583893            2.843888    107.999198
# min     2000.000000            1.000000      0.000000
# 25%     2199.000000            6.000000     82.000000
# 50%     2768.000000            8.000000    176.000000
# 75%     3796.000000           10.000000    270.000000
# max     4883.000000           12.000000    363.000000

# %%
#Only the transactions made in the last 2 years are considered for the analysis.
transactions_exsistingcustomer=transactions_exsistingcustomer[transactions_exsistingcustomer['recency'] < 730]
transactions_exsistingcustomer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14054 entries, 0 to 19444
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   product_id                           14054 non-null  int64
#  1   customer_id                          14054 non-null  int64
#  2   transaction_date                     14054 non-null  object
#  3   online_order                         14054 non-null  float64
#  4   order_status                         14054 non-null  object
#  5   brand                                14054 non-null  object
#  6   product_line                         14054 non-null  object
#  7   product_class                        14054 non-null  object
#  8   product_size                         14054 non-null  object
#  9   list_price                           14054 non-null  float64
#  10  standard_cost                        14054 non-null  float64
#  11  product_first_sold_date              14054 non-null  datetime64[ns]
#  12  profit                               14054 non-null  float64
#  13  gender                               14054 non-null  object
#  14  past_3_years_bike_related_purchases  14054 non-null  float64
#  15  age                                  14054 non-null  float64
#  16  age_group                            14054 non-null  category
#  17  job_title                            14054 non-null  object
#  18  job_industry_category                14054 non-null  object
#  19  wealth_segment                       14054 non-null  object
#  20  owns_car                             14054 non-null  object
#  21  postcode                             14054 non-null  float64
#  22  state                                14054 non-null  object
#  23  property_valuation                   14054 non-null  float64
#  24  country                              14054 non-null  object
#  25  recency                              14054 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(8), int64(3), object(13)
# memory usage: 2.8+ MB

# %%
rfmTable = transactions_exsistingcustomer.groupby('customer_id').agg({'recency': lambda x:x.min(), 
                                                                      'product_id': lambda x: len(x), 
                                                                      'profit': lambda x: x.sum()})

rfmTable.rename(columns={'recency': 'recency', 
                         'product_id': 'frequency', 
                         'profit': 'monetary_value'}, inplace=True)

# %%
rfmTable.head()
# Out:
#              recency  frequency  monetary_value
# customer_id
# 1                  7         11         3018.09
# 2                116          3         2226.26
# 9                103          6         2353.11
# 12                82          7         3540.03
# 13                 1          7         4337.38

# %%
rfmTable
# Out:
#              recency  frequency  monetary_value
# customer_id
# 1                  7         11         3018.09
# 2                116          3         2226.26
# 9                103          6         2353.11
# 12                82          7         3540.03
# 13                 1          7         4337.38
# ...              ...        ...             ...
# 3493              19          6         3728.88
# 3494               0          4         2755.11
# 3495              12          7         3847.65
# 3496               6          4         2045.84
# 3497             106          3         1648.32
#
# [2522 rows x 3 columns]

# %%
rfmTable["monetary_value"] = rfmTable["monetary_value"].astype(int)

# %%
quartiles = rfmTable.quantile(q=[0,0.25,0.50,0.75,0.99])
print(quartiles, type(quartiles))
# Out:
#       recency  frequency  monetary_value
# 0.00     0.00       1.00            15.0
# 0.25     8.00       4.00          1785.5
# 0.50    35.00       5.00          2799.0
# 0.75    76.75       7.00          4096.0
# 0.99   251.00      11.79          8252.0 <class 'pandas.core.frame.DataFrame'>

# %%
rfmTable["R_Score"] = 0
rfmTable["F_Score"] = 0
rfmTable["M_Score"] = 0

rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score
# customer_id
# 1                  7         11            3018        0        0        0
# 2                116          3            2226        0        0        0
# 9                103          6            2353        0        0        0
# 12                82          7            3540        0        0        0
# 13                 1          7            4337        0        0        0
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        0        0        0
# 3494               0          4            2755        0        0        0
# 3495              12          7            3847        0        0        0
# 3496               6          4            2045        0        0        0
# 3497             106          3            1648        0        0        0
#
# [2522 rows x 6 columns]

# %%
#Calculating R_Score
rfmTable.index

for i in rfmTable.index:
    if (int(rfmTable["recency"][i])) > 76:
        rfmTable["R_Score"][i] = 1
    elif ((int(rfmTable["recency"][i])) <=76) & ((int(rfmTable["recency"][i])) > 35):
        rfmTable["R_Score"][i] = 2
    elif ((int(rfmTable["recency"][i])) <=35) & ((int(rfmTable["recency"][i])) > 8):
        rfmTable["R_Score"][i] = 3
    else:
        rfmTable["R_Score"][i] = 4
        
rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score
# customer_id
# 1                  7         11            3018        4        0        0
# 2                116          3            2226        1        0        0
# 9                103          6            2353        1        0        0
# 12                82          7            3540        1        0        0
# 13                 1          7            4337        4        0        0
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        3        0        0
# 3494               0          4            2755        4        0        0
# 3495              12          7            3847        3        0        0
# 3496               6          4            2045        4        0        0
# 3497             106          3            1648        1        0        0
#
# [2522 rows x 6 columns]

# %%
#Calculating F_Score

for i in rfmTable.index:
    if (int(rfmTable["frequency"][i])) > 7:
        rfmTable["F_Score"][i] = 4
    elif ((int(rfmTable["frequency"][i])) <=7) & ((int(rfmTable["frequency"][i])) > 5):
        rfmTable["F_Score"][i] = 3
    elif ((int(rfmTable["frequency"][i])) <=5) & ((int(rfmTable["frequency"][i])) > 4):
        rfmTable["F_Score"][i] = 2
    else:
        rfmTable["F_Score"][i] = 1
        
rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score
# customer_id
# 1                  7         11            3018        4        4        0
# 2                116          3            2226        1        1        0
# 9                103          6            2353        1        3        0
# 12                82          7            3540        1        3        0
# 13                 1          7            4337        4        3        0
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        3        3        0
# 3494               0          4            2755        4        1        0
# 3495              12          7            3847        3        3        0
# 3496               6          4            2045        4        1        0
# 3497             106          3            1648        1        1        0
#
# [2522 rows x 6 columns]

# %%
#Calculating M_Score

for i in rfmTable.index:
    if (int(rfmTable["monetary_value"][i])) > 4096:
        rfmTable["M_Score"][i] = 4
    elif ((int(rfmTable["monetary_value"][i])) <=4096) & ((int(rfmTable["monetary_value"][i])) > 2799):
        rfmTable["M_Score"][i] = 3
    elif ((int(rfmTable["monetary_value"][i])) <=2799) & ((int(rfmTable["monetary_value"][i])) > 1785):
        rfmTable["M_Score"][i] = 2
    else:
        rfmTable["M_Score"][i] = 1
        

rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score
# customer_id
# 1                  7         11            3018        4        4        3
# 2                116          3            2226        1        1        2
# 9                103          6            2353        1        3        2
# 12                82          7            3540        1        3        3
# 13                 1          7            4337        4        3        4
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        3        3        3
# 3494               0          4            2755        4        1        2
# 3495              12          7            3847        3        3        3
# 3496               6          4            2045        4        1        2
# 3497             106          3            1648        1        1        1
#
# [2522 rows x 6 columns]

# %%
rfmTable["RFM_Value"] = 0

for i in rfmTable.index:
    rfmTable["RFM_Value"][i] = (100*rfmTable["R_Score"][i]) + (10*rfmTable["F_Score"][i]) + rfmTable["M_Score"][i]
    
rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score  \
# customer_id
# 1                  7         11            3018        4        4        3
# 2                116          3            2226        1        1        2
# 9                103          6            2353        1        3        2
# 12                82          7            3540        1        3        3
# 13                 1          7            4337        4        3        4
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        3        3        3
# 3494               0          4            2755        4        1        2
# 3495              12          7            3847        3        3        3
# 3496               6          4            2045        4        1        2
# 3497             106          3            1648        1        1        1
#
#              RFM_Value
# customer_id
# 1                  443
# 2                  112
# 9                  132
# 12                 133
# 13                 434
# ...                ...
# 3493               333
# 3494               412
# 3495               333
# 3496               412
# 3497               111
#
# [2522 rows x 7 columns]

# %%
quartiles = rfmTable["RFM_Value"].quantile(q=[0,0.25,0.50,0.75,0.99])
print(quartiles, type(quartiles))
# Out:
# 0.00    111.00
# 0.25    160.75
# 0.50    311.00
# 0.75    411.00
# 0.99    444.00
# Name: RFM_Value, dtype: float64 <class 'pandas.core.series.Series'>

# %%
rfmTable["Customer_Profile"] = " "

# %%
for i in rfmTable.index:
    if (int(rfmTable["RFM_Value"][i])) > 411:
        rfmTable["Customer_Profile"][i] = "Platinum Customer"
    elif ((int(rfmTable["RFM_Value"][i])) <=411) & ((int(rfmTable["RFM_Value"][i])) > 311):
        rfmTable["Customer_Profile"][i] = "Silver Customer"
    elif ((int(rfmTable["RFM_Value"][i])) <=311) & ((int(rfmTable["RFM_Value"][i])) > 160):
        rfmTable["Customer_Profile"][i] = "Gold Customer"
    else:
        rfmTable["Customer_Profile"][i] = "Bronze Customer"
        
rfmTable
# Out:
#              recency  frequency  monetary_value  R_Score  F_Score  M_Score  \
# customer_id
# 1                  7         11            3018        4        4        3
# 2                116          3            2226        1        1        2
# 9                103          6            2353        1        3        2
# 12                82          7            3540        1        3        3
# 13                 1          7            4337        4        3        4
# ...              ...        ...             ...      ...      ...      ...
# 3493              19          6            3728        3        3        3
# 3494               0          4            2755        4        1        2
# 3495              12          7            3847        3        3        3
# 3496               6          4            2045        4        1        2
# 3497             106          3            1648        1        1        1
#
#              RFM_Value   Customer_Profile
# customer_id
# 1                  443  Platinum Customer
# 2                  112    Bronze Customer
# 9                  132    Bronze Customer
# 12                 133    Bronze Customer
# 13                 434  Platinum Customer
# ...                ...                ...
# 3493               333    Silver Customer
# 3494               412  Platinum Customer
# 3495               333    Silver Customer
# 3496               412  Platinum Customer
# 3497               111    Bronze Customer
#
# [2522 rows x 8 columns]

# %%
rfmTable.groupby(["Customer_Profile"])["RFM_Value"].sum()
# Out:
# Customer_Profile
# Bronze Customer       76059
# Gold Customer        165845
# Platinum Customer    242199
# Silver Customer      213159
# Name: RFM_Value, dtype: int64

# %%
df_customerprofile = rfmTable.groupby(["Customer_Profile"])["RFM_Value"].sum()
df_customerprofile
# Out:
# Customer_Profile
# Bronze Customer       76059
# Gold Customer        165845
# Platinum Customer    242199
# Silver Customer      213159
# Name: RFM_Value, dtype: int64

# %% [markdown]
# ### Data visualization

# %%
pd.set_option('display.max_colwidth', -1)
plt.figure(figsize=[8,3])
plt.style.use('seaborn-whitegrid')
sns.set_context('notebook')


rfmTable.groupby(["Customer_Profile"])["RFM_Value"].sum().plot(kind="bar", 
                          align='center',width=0.5,edgecolor='Grey' ,color=["blue","orange","red","green"])

plt.title("Customer Profile Vs. Customer Value\n", fontsize=18)
plt.xlabel("\nCustomer Profile", fontsize=14,color="black")
plt.ylabel("Customer Value\n",fontsize=14, color="black")



plt.xticks(rotation=0)    

    
plt.show()

# %% [markdown]
# ##### OBSERVATIONS
#
# **Platinum Customer** has high customer value as compared to other customer profiles.

# %% [markdown]
# #### Age Cluster to shows which wealth segment brings more profit on the tabel

# %%
res1 = pd.pivot_table(data=transactions_exsistingcustomer, index="age_group", 
                      columns="wealth_segment", values="profit",aggfunc=np.sum)
res1
# Out:
# wealth_segment  Affluent Customer  High Net Worth  Mass Customer
# age_group
# <30             396007.92          335764.77       692526.75
# 30-40           334178.62          372241.23       681114.78
# 40-50           626030.45          681495.37       1356499.08
# 50-60           340137.99          360956.51       676747.74
# 60+             233502.02          215472.67       449430.01

# %%
res1["Affluent Customer"] = res1["Affluent Customer"].astype(int)
res1["High Net Worth"] = res1["High Net Worth"].astype(int)
res1["Mass Customer"] = res1["Mass Customer"].astype(int)

res1
# Out:
# wealth_segment  Affluent Customer  High Net Worth  Mass Customer
# age_group
# <30             396007             335764          692526
# 30-40           334178             372241          681114
# 40-50           626030             681495          1356499
# 50-60           340137             360956          676747
# 60+             233502             215472          449430

# %%
pd.pivot_table(data=transactions_exsistingcustomer, index="age_group", columns="wealth_segment", values="profit",aggfunc=np.sum).plot(kind='bar')
plt.title("Profit Vs. Age Group in terms of Wealth Segment\n", fontsize=18)
plt.xlabel("\nAge Group\n", fontsize=13,color="black")
plt.ylabel("Profit in Dollars\n",fontsize=13, color="black")
plt.legend(loc='upper right',fontsize=10)
plt.xticks(rotation=0)


plt.figure(figsize=[15,6])
plt.subplot(1,2,1)

plt.title("Profit Heatmap- Age Group Vs. Wealth Segment\n", fontsize=18)
ax = sns.heatmap(res1, annot=True, cmap="RdYlGn", fmt='d')
ax.tick_params(axis='both', which='both', length=0)
plt.xlabel("\nAge Group", fontsize=13,color="black")
plt.ylabel("Wealth Segment\n",fontsize=13,color="black")
plt.show()

plt.show()

# %% [markdown]
# #### OBSERVATIONS
# From the above heatmap and bar graph
#
# - Age Group **40-50** giving the highest profit.
# - Based on that the wealth segment **Mass Customers** has overall performance better.

# %%
#Finding number of cars owned as per the location
transactions_exsistingcustomer.columns
# Out:
# Index(['product_id', 'customer_id', 'transaction_date', 'online_order',
#        'order_status', 'brand', 'product_line', 'product_class',
#        'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'profit', 'gender',
#        'past_3_years_bike_related_purchases', 'age', 'age_group', 'job_title',
#        'job_industry_category', 'wealth_segment', 'owns_car', 'postcode',
#        'state', 'property_valuation', 'country', 'recency'],
#       dtype='object')

# %%
transactions_exsistingcustomer["owns_car"].value_counts()
# Out:
# Yes    7111
# No     6943
# Name: owns_car, dtype: int64

# %%
transactions_exsistingcustomer["owns_car_flag"]=np.where(transactions_exsistingcustomer["owns_car"]=="Yes",1,0)

# %%
transactions_exsistingcustomer.groupby(["state","owns_car"])["owns_car_flag"].count()
# Out:
# state            owns_car
# New South Wales  No          3647
#                  Yes         3791
# QLD              No          1555
#                  Yes         1555
# Victoria         No          1741
#                  Yes         1765
# Name: owns_car_flag, dtype: int64

# %%
pd.pivot_table(data=transactions_exsistingcustomer, index="state", 
               columns="owns_car", values="owns_car_flag",
               aggfunc='count').plot(kind='bar',cmap='Pastel2',figsize=[10,5])
plt.title("Number of Cars Owned in Each State\n", fontsize=18)
plt.xlabel("\nState Wise Owned Car", fontsize=14,color="black")
plt.ylabel("Number of Cars\n",fontsize=14, color="black")
plt.legend(loc='upper right',fontsize=14)
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# #### OBSERVATIONS
#
# **New South Wales** holds high number of owned cars as compared to other states of Australia.

# %% [markdown]
# #### Find total bikes purchased by each customer based on his/her job_industry

# %%
transactions_exsistingcustomer.columns
# Out:
# Index(['product_id', 'customer_id', 'transaction_date', 'online_order',
#        'order_status', 'brand', 'product_line', 'product_class',
#        'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'profit', 'gender',
#        'past_3_years_bike_related_purchases', 'age', 'age_group', 'job_title',
#        'job_industry_category', 'wealth_segment', 'owns_car', 'postcode',
#        'state', 'property_valuation', 'country', 'recency', 'owns_car_flag'],
#       dtype='object')

# %%
transactions_exsistingcustomer.groupby("job_industry_category")["past_3_years_bike_related_purchases"].count()
# Out:
# job_industry_category
# Argiculture           485
# Entertainment         625
# Financial Services    3341
# Health                2733
# IT                    584
# Manufacturing         3432
# Property              1091
# Retail                1451
# Telecommunications    312
# Name: past_3_years_bike_related_purchases, dtype: int64

# %%
plt.figure(figsize=[15,8])

transactions_exsistingcustomer.groupby("job_industry_category")["past_3_years_bike_related_purchases"].count().plot(kind='bar',figsize=[15,5],
                                                   cmap='jet',  width=0.5)
plt.title("Bike Related Purchases Based on industry\n", fontsize=20)
plt.xlabel("\nJob Industry Category", fontsize=16,color="black")
plt.ylabel("Past three years bike purchased\n",fontsize=16, color="black")
plt.xticks(rotation=0)
plt.yticks(np.arange(0,4500,500))

plt.legend(loc='upper right',fontsize=13)

label = transactions_exsistingcustomer.groupby("job_industry_category")["past_3_years_bike_related_purchases"].count()

for i in range(9):
    plt.text(x = i, y = label[i], s = str("\n"+str(int(label[i]))+"\n"),horizontalalignment='center',rotation = 360, color = "black", fontsize=11)

plt.show()

# %% [markdown]
# #### OBSERVATIONS
#
# Industry like - **Manufacturing & Financial Services** holds a high record in terms of bike purchased in last 3 years.

# %% [markdown]
# #### Find which industry sector brings up the highest profit on the tabel

# %%
transactions_exsistingcustomer.groupby("job_industry_category")["profit"].sum().round()
# Out:
# job_industry_category
# Argiculture           256388.0
# Entertainment         345259.0
# Financial Services    1898996.0
# Health                1480275.0
# IT                    318906.0
# Manufacturing         1868154.0
# Property              597923.0
# Retail                818723.0
# Telecommunications    167483.0
# Name: profit, dtype: float64

# %%
transactions_exsistingcustomer.groupby("job_industry_category")["profit"].sum().plot(kind='bar',figsize=[15,5], cmap= 'summer', width=0.6)
plt.title("Profit in terms of Job Industry\n", fontsize=20)
plt.xlabel("\nJob Industry Category", fontsize=16,color="black")
plt.ylabel("Profit in Dolalrs\n",fontsize=16, color="black")
plt.xticks(rotation=0)
plt.yticks(np.arange(150000,2500000,250000))
plt.legend(loc='upper right',fontsize=13)

label = transactions_exsistingcustomer.groupby("job_industry_category")["profit"].sum().round()
for i in range(9):
    plt.text(x = i, y = label[i], s = str("\n"+"$"+str(int(label[i]))+"\n"),horizontalalignment='center',rotation = 360, color = "black", fontsize=11)

plt.show()

# %% [markdown]
# #### OBSERVATIONS
#
# Industry like - **Manufacturing & Financial Services** holds high profit.

# %% [markdown]
# #### Find the past 3 years bike purachsed on the bases of gender and age group

# %%
pd.pivot_table(data=transactions_exsistingcustomer, index="gender", 
               columns="age_group", values="past_3_years_bike_related_purchases",
               aggfunc='count')
# Out:
# age_group   <30  30-40  40-50  50-60  60+
# gender
# Female     1280  1248   2536   1235   836
# Male       1324  1207   2354   1202   832

# %%
pd.pivot_table(data=transactions_exsistingcustomer, index="gender", 
               columns="age_group", values="past_3_years_bike_related_purchases",
               aggfunc='count').plot(kind='bar',cmap='tab20b',figsize=[9,5])

plt.title("Bike Purchased w.r.t Gender - Subcategory: Age Group\n", fontsize=16)
plt.xlabel("\nGender", fontsize=14,color="black")
plt.ylabel("Number of bike purchased in last 3 years\n",fontsize=11, color="black")
plt.legend(loc='upper right',fontsize=12)
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# #### OBSERVATIONS
#
# Age group **40-50** has high count in terms of bike purchased in last 3 years within that **Female ratio** a bit higher.

# %% [markdown]
# ### Data Frame of Only High Value Customers

# %%
transactions_exsistingcustomer.columns
# Out:
# Index(['product_id', 'customer_id', 'transaction_date', 'online_order',
#        'order_status', 'brand', 'product_line', 'product_class',
#        'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'profit', 'gender',
#        'past_3_years_bike_related_purchases', 'age', 'age_group', 'job_title',
#        'job_industry_category', 'wealth_segment', 'owns_car', 'postcode',
#        'state', 'property_valuation', 'country', 'recency', 'owns_car_flag'],
#       dtype='object')

# %%
df1 = transactions_exsistingcustomer[transactions_exsistingcustomer["age_group"]=="40-50"]
df1
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 1      3           3120         2017-05-21       1.0           Approved
# 2      37          402          2017-10-16       0.0           Approved
# 6      22          1542         2017-04-21       1.0           Approved
# 11     61          2783         2017-01-05       1.0           Approved
# 15     3           2961         2017-10-10       0.0           Approved
# ...   ..            ...                ...       ...                ...
# 19421  44          1102         2017-12-11       0.0           Approved
# 19434  55          135          2017-07-23       1.0           Cancelled
# 19439  9           718          2017-11-07       1.0           Approved
# 19441  41          127          2017-12-19       1.0           Approved
# 19442  87          2284         2017-05-10       1.0           Approved
#
#                brand product_line product_class product_size  list_price  ...  \
# 1      Trek Bicycles  Standard     medium        large        2091.47     ...
# 2      OHM Cycles     Standard     low           medium       1793.43     ...
# 6      WeareA2B       Standard     medium        medium       60.34       ...
# 11     OHM Cycles     Standard     low           medium       71.16       ...
# 15     Trek Bicycles  Standard     medium        large        2091.47     ...
# ...              ...       ...        ...          ...            ...     ...
# 19421  WeareA2B       Standard     medium        medium       1769.64     ...
# 19434  Trek Bicycles  Road         medium        large        1894.19     ...
# 19439  OHM Cycles     Road         medium        medium       742.54      ...
# 19441  Solex          Road         medium        medium       416.98      ...
# 19442  OHM Cycles     Standard     medium        medium       1636.90     ...
#
#                         job_title job_industry_category     wealth_segment  \
# 1      Clinical Specialist         Health                Mass Customer
# 2      Desktop Support Technician  Retail                Affluent Customer
# 6      Food Chemist                Health                Mass Customer
# 11     Sales Representative        Retail                Affluent Customer
# 15     Assistant Manager           Health                Mass Customer
# ...                  ...              ...                          ...
# 19421  Recruiting Manager          Manufacturing         Affluent Customer
# 19434  Internal Auditor            IT                    Mass Customer
# 19439  Engineer I                  Manufacturing         Mass Customer
# 19441  Compensation Analyst        Financial Services    Mass Customer
# 19442  Staff Accountant IV         Telecommunications    High Net Worth
#
#       owns_car  postcode            state property_valuation    country  \
# 1      Yes      2196.0    New South Wales  5.0                Australia
# 2      No       2835.0    New South Wales  1.0                Australia
# 6      Yes      2155.0    New South Wales  10.0               Australia
# 11     Yes      2171.0    New South Wales  9.0                Australia
# 15     Yes      3031.0    Victoria         8.0                Australia
# ...    ...         ...         ...         ...                      ...
# 19421  No       2647.0    New South Wales  3.0                Australia
# 19434  No       3201.0    Victoria         6.0                Australia
# 19439  Yes      4217.0    QLD              11.0               Australia
# 19441  No       4405.0    QLD              1.0                Australia
# 19442  No       3630.0    Victoria         1.0                Australia
#
#       recency owns_car_flag
# 1      223     1
# 2      75      0
# 6      253     1
# 11     359     1
# 15     81      1
# ...    ..     ..
# 19421  19      0
# 19434  160     0
# 19439  53      1
# 19441  11      0
# 19442  234     0
#
# [4890 rows x 27 columns]

# %%
df2 = df1[df1["wealth_segment"]=="Mass Customer"]
df2
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 1      3           3120         2017-05-21       1.0           Approved
# 6      22          1542         2017-04-21       1.0           Approved
# 15     3           2961         2017-10-10       0.0           Approved
# 17     33          1842         2017-06-02       0.0           Approved
# 20     27          1582         2017-10-09       0.0           Approved
# ...    ..           ...                ...       ...                ...
# 19394  85          3336         2017-12-29       1.0           Approved
# 19405  42          3196         2017-05-29       0.0           Approved
# 19434  55          135          2017-07-23       1.0           Cancelled
# 19439  9           718          2017-11-07       1.0           Approved
# 19441  41          127          2017-12-19       1.0           Approved
#
#                 brand product_line product_class product_size  list_price  \
# 1      Trek Bicycles   Standard     medium        large        2091.47
# 6      WeareA2B        Standard     medium        medium       60.34
# 15     Trek Bicycles   Standard     medium        large        2091.47
# 17     Giant Bicycles  Standard     medium        small        1311.44
# 20     Trek Bicycles   Standard     medium        medium       499.53
# ...              ...        ...        ...           ...          ...
# 19394  WeareA2B        Standard     medium        medium       752.64
# 19405  OHM Cycles      Road         medium        small        1810.00
# 19434  Trek Bicycles   Road         medium        large        1894.19
# 19439  OHM Cycles      Road         medium        medium       742.54
# 19441  Solex           Road         medium        medium       416.98
#
#        ...              job_title job_industry_category  wealth_segment  \
# 1      ...  Clinical Specialist    Health                Mass Customer
# 6      ...  Food Chemist           Health                Mass Customer
# 15     ...  Assistant Manager      Health                Mass Customer
# 17     ...  Accountant IV          Financial Services    Mass Customer
# 20     ...  Office Assistant III   Property              Mass Customer
# ...    ...                   ...        ...                        ...
# 19394  ...  Research Assistant IV  Manufacturing         Mass Customer
# 19405  ...  Engineer IV            Health                Mass Customer
# 19434  ...  Internal Auditor       IT                    Mass Customer
# 19439  ...  Engineer I             Manufacturing         Mass Customer
# 19441  ...  Compensation Analyst   Financial Services    Mass Customer
#
#       owns_car  postcode            state property_valuation    country  \
# 1      Yes      2196.0    New South Wales  5.0                Australia
# 6      Yes      2155.0    New South Wales  10.0               Australia
# 15     Yes      3031.0    Victoria         8.0                Australia
# 17     No       2250.0    New South Wales  8.0                Australia
# 20     No       2101.0    New South Wales  11.0               Australia
# ...    ..          ...                ...   ...                     ...
# 19394  Yes      4820.0    QLD              1.0                Australia
# 19405  No       3977.0    Victoria         7.0                Australia
# 19434  No       3201.0    Victoria         6.0                Australia
# 19439  Yes      4217.0    QLD              11.0               Australia
# 19441  No       4405.0    QLD              1.0                Australia
#
#       recency owns_car_flag
# 1      223     1
# 6      253     1
# 15     81      1
# 17     211     0
# 20     82      0
# ...    ..     ..
# 19394  1       1
# 19405  215     0
# 19434  160     0
# 19439  53      1
# 19441  11      0
#
# [2487 rows x 27 columns]

# %%
FS = df2[df2["job_industry_category"] == "Financial Services"]
FS
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 17     33          1842         2017-06-02       0.0           Approved
# 21     37          595          2017-06-29       1.0           Approved
# 40     44          2570         2017-05-08       1.0           Approved
# 94     45          757          2017-02-26       0.0           Approved
# 102    78          1468         2017-11-12       0.0           Approved
# ...    ..           ...                ...       ...                ...
# 19312  38          122          2017-03-02       0.0           Approved
# 19318  2           3420         2017-10-22       1.0           Approved
# 19327  93          326          2017-12-01       0.0           Approved
# 19381  37          648          2017-10-29       1.0           Approved
# 19441  41          127          2017-12-19       1.0           Approved
#
#                 brand product_line product_class product_size  list_price  \
# 17     Giant Bicycles  Standard     medium        small        1311.44
# 21     OHM Cycles      Standard     low           medium       1793.43
# 40     WeareA2B        Standard     medium        medium       1769.64
# 94     Solex           Standard     medium        medium       441.49
# 102    Giant Bicycles  Standard     medium        large        1765.30
# ...               ...       ...        ...          ...            ...
# 19312  Solex           Standard     medium        medium       1577.53
# 19318  Solex           Standard     medium        medium       71.49
# 19327  WeareA2B        Standard     medium        medium       1065.03
# 19381  OHM Cycles      Standard     low           medium       1793.43
# 19441  Solex           Road         medium        medium       416.98
#
#        ...                   job_title job_industry_category  wealth_segment  \
# 17     ...  Accountant IV               Financial Services    Mass Customer
# 21     ...  VP Marketing                Financial Services    Mass Customer
# 40     ...  Professor                   Financial Services    Mass Customer
# 94     ...  Environmental Tech          Financial Services    Mass Customer
# 102    ...  Financial Advisor           Financial Services    Mass Customer
# ...    ...                ...                          ...              ...
# 19312  ...  Quality Control Specialist  Financial Services    Mass Customer
# 19318  ...  Financial Advisor           Financial Services    Mass Customer
# 19327  ...  Help Desk Operator          Financial Services    Mass Customer
# 19381  ...  Accountant II               Financial Services    Mass Customer
# 19441  ...  Compensation Analyst        Financial Services    Mass Customer
#
#       owns_car  postcode            state property_valuation    country  \
# 17     No       2250.0    New South Wales  8.0                Australia
# 21     No       4305.0    QLD              4.0                Australia
# 40     Yes      4812.0    QLD              3.0                Australia
# 94     No       4019.0    QLD              8.0                Australia
# 102    No       2519.0    New South Wales  9.0                Australia
# ...    ..          ...                ...  ...                      ...
# 19312  Yes      4817.0    QLD              2.0                Australia
# 19318  Yes      4118.0    QLD              5.0                Australia
# 19327  No       2515.0    New South Wales  10.0               Australia
# 19381  Yes      4551.0    QLD              7.0                Australia
# 19441  No       4405.0    QLD              1.0                Australia
#
#       recency owns_car_flag
# 17     211     0
# 21     184     0
# 40     236     1
# 94     307     0
# 102    48      0
# ...    ..     ..
# 19312  303     1
# 19318  69      1
# 19327  29      0
# 19381  62      1
# 19441  11      0
#
# [498 rows x 27 columns]

# %%
M = df2[df2["job_industry_category"] == "Manufacturing"]
M
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 22     37          2001         2017-04-08       1.0           Approved
# 83     33          3297         2017-11-02       1.0           Approved
# 96     80          211          2017-05-31       1.0           Approved
# 117    64          1591         2017-03-21       0.0           Approved
# 119    25          50           2017-06-16       0.0           Approved
# ...    ..          ..                  ...       ...                ...
# 19270  3           2312         2017-01-22       0.0           Cancelled
# 19299  7           3072         2017-04-12       0.0           Approved
# 19314  61          2496         2017-02-21       0.0           Approved
# 19394  85          3336         2017-12-29       1.0           Approved
# 19439  9           718          2017-11-07       1.0           Approved
#
#                 brand product_line product_class product_size  list_price  \
# 22     OHM Cycles      Standard     low           medium       1793.43
# 83     Giant Bicycles  Standard     medium        small        1311.44
# 96     OHM Cycles      Touring      low           medium       1073.07
# 117    Trek Bicycles   Standard     medium        large        1469.44
# 119    Giant Bicycles  Road         medium        medium       1538.99
# ...               ...   ...            ...           ...           ...
# 19270  Trek Bicycles   Standard     medium        large        2091.47
# 19299  Trek Bicycles   Road         low           medium       980.37
# 19314  OHM Cycles      Standard     low           medium       71.16
# 19394  WeareA2B        Standard     medium        medium       752.64
# 19439  OHM Cycles      Road         medium        medium       742.54
#
#        ...                      job_title job_industry_category  \
# 22     ...  Analog Circuit Design manager  Manufacturing
# 83     ...  Product Engineer               Manufacturing
# 96     ...  VP Marketing                   Manufacturing
# 117    ...  Operator                       Manufacturing
# 119    ...  Account Executive              Manufacturing
# ...    ...                ...                        ...
# 19270  ...  Assistant Manager              Manufacturing
# 19299  ...  Chemical Engineer              Manufacturing
# 19314  ...  Web Developer II               Manufacturing
# 19394  ...  Research Assistant IV          Manufacturing
# 19439  ...  Engineer I                     Manufacturing
#
#        wealth_segment owns_car  postcode            state property_valuation  \
# 22     Mass Customer   Yes      2800.0    New South Wales  4.0
# 83     Mass Customer   No       3213.0    Victoria         6.0
# 96     Mass Customer   Yes      2159.0    New South Wales  10.0
# 117    Mass Customer   Yes      2073.0    New South Wales  12.0
# 119    Mass Customer   Yes      2047.0    New South Wales  10.0
# ...              ...   ...         ...                ...   ...
# 19270  Mass Customer   No       4350.0    QLD              2.0
# 19299  Mass Customer   Yes      2323.0    New South Wales  5.0
# 19314  Mass Customer   Yes      4551.0    QLD              7.0
# 19394  Mass Customer   Yes      4820.0    QLD              1.0
# 19439  Mass Customer   Yes      4217.0    QLD              11.0
#
#          country recency owns_car_flag
# 22     Australia  266     1
# 83     Australia  58      0
# 96     Australia  213     1
# 117    Australia  284     1
# 119    Australia  197     1
# ...          ...  ...    ..
# 19270  Australia  342     0
# 19299  Australia  262     1
# 19314  Australia  312     1
# 19394  Australia  1       1
# 19439  Australia  53      1
#
# [616 rows x 27 columns]

# %%
H = df2[df2["job_industry_category"] == "Health"]
H
# Out:
#        product_id  customer_id transaction_date  online_order order_status  \
# 1      3           3120         2017-05-21       1.0           Approved
# 6      22          1542         2017-04-21       1.0           Approved
# 15     3           2961         2017-10-10       0.0           Approved
# 26     64          2666         2017-04-11       1.0           Approved
# 130    12          1937         2017-01-18       0.0           Approved
# ...    ..           ...                ...       ...                ...
# 19120  49          650          2017-02-13       1.0           Approved
# 19188  45          2115         2017-06-04       0.0           Approved
# 19241  59          528          2017-10-13       1.0           Approved
# 19286  29          650          2017-08-31       0.0           Approved
# 19405  42          3196         2017-05-29       0.0           Approved
#
#                 brand product_line product_class product_size  list_price  \
# 1      Trek Bicycles   Standard     medium        large        2091.47
# 6      WeareA2B        Standard     medium        medium       60.34
# 15     Trek Bicycles   Standard     medium        large        2091.47
# 26     Trek Bicycles   Standard     medium        large        1469.44
# 130    WeareA2B        Standard     medium        medium       1231.15
# ...         ...             ...        ...           ...           ...
# 19120  Trek Bicycles   Road         medium        medium       533.51
# 19188  Solex           Standard     medium        medium       441.49
# 19241  Solex           Standard     medium        large        1061.56
# 19286  Norco Bicycles  Road         medium        medium       543.39
# 19405  OHM Cycles      Road         medium        small        1810.00
#
#        ...               job_title job_industry_category  wealth_segment  \
# 1      ...  Clinical Specialist     Health                Mass Customer
# 6      ...  Food Chemist            Health                Mass Customer
# 15     ...  Assistant Manager       Health                Mass Customer
# 26     ...  Occupational Therapist  Health                Mass Customer
# 130    ...  Quality Engineer        Health                Mass Customer
# ...    ...               ...           ...                          ...
# 19120  ...  Assistant Manager       Health                Mass Customer
# 19188  ...  Food Chemist            Health                Mass Customer
# 19241  ...  Registered Nurse        Health                Mass Customer
# 19286  ...  Assistant Manager       Health                Mass Customer
# 19405  ...  Engineer IV             Health                Mass Customer
#
#       owns_car  postcode            state property_valuation    country  \
# 1      Yes      2196.0    New South Wales  5.0                Australia
# 6      Yes      2155.0    New South Wales  10.0               Australia
# 15     Yes      3031.0    Victoria         8.0                Australia
# 26     No       2151.0    New South Wales  8.0                Australia
# 130    No       2619.0    New South Wales  3.0                Australia
# ...    ..          ...                ...  ...                      ...
# 19120  No       2565.0    New South Wales  7.0                Australia
# 19188  Yes      3143.0    Victoria         4.0                Australia
# 19241  No       2576.0    New South Wales  10.0               Australia
# 19286  No       2565.0    New South Wales  7.0                Australia
# 19405  No       3977.0    Victoria         7.0                Australia
#
#       recency owns_car_flag
# 1      223     1
# 6      253     1
# 15     81      1
# 26     263     0
# 130    346     0
# ...    ...    ..
# 19120  320     0
# 19188  209     1
# 19241  78      0
# 19286  121     0
# 19405  215     0
#
# [587 rows x 27 columns]

# %%
FS = pd.concat([FS, M], ignore_index=True, sort=False)
FS
# Out:
#       product_id  customer_id transaction_date  online_order order_status  \
# 0     33          1842         2017-06-02       0.0           Approved
# 1     37          595          2017-06-29       1.0           Approved
# 2     44          2570         2017-05-08       1.0           Approved
# 3     45          757          2017-02-26       0.0           Approved
# 4     78          1468         2017-11-12       0.0           Approved
# ...   ..           ...                ...       ...                ...
# 1109  3           2312         2017-01-22       0.0           Cancelled
# 1110  7           3072         2017-04-12       0.0           Approved
# 1111  61          2496         2017-02-21       0.0           Approved
# 1112  85          3336         2017-12-29       1.0           Approved
# 1113  9           718          2017-11-07       1.0           Approved
#
#                brand product_line product_class product_size  list_price  ...  \
# 0     Giant Bicycles  Standard     medium        small        1311.44     ...
# 1     OHM Cycles      Standard     low           medium       1793.43     ...
# 2     WeareA2B        Standard     medium        medium       1769.64     ...
# 3     Solex           Standard     medium        medium       441.49      ...
# 4     Giant Bicycles  Standard     medium        large        1765.30     ...
# ...              ...       ...        ...          ...            ...     ...
# 1109  Trek Bicycles   Standard     medium        large        2091.47     ...
# 1110  Trek Bicycles   Road         low           medium       980.37      ...
# 1111  OHM Cycles      Standard     low           medium       71.16       ...
# 1112  WeareA2B        Standard     medium        medium       752.64      ...
# 1113  OHM Cycles      Road         medium        medium       742.54      ...
#
#                   job_title job_industry_category  wealth_segment owns_car  \
# 0     Accountant IV          Financial Services    Mass Customer   No
# 1     VP Marketing           Financial Services    Mass Customer   No
# 2     Professor              Financial Services    Mass Customer   Yes
# 3     Environmental Tech     Financial Services    Mass Customer   No
# 4     Financial Advisor      Financial Services    Mass Customer   No
# ...                 ...                     ...              ...   ..
# 1109  Assistant Manager      Manufacturing         Mass Customer   No
# 1110  Chemical Engineer      Manufacturing         Mass Customer   Yes
# 1111  Web Developer II       Manufacturing         Mass Customer   Yes
# 1112  Research Assistant IV  Manufacturing         Mass Customer   Yes
# 1113  Engineer I             Manufacturing         Mass Customer   Yes
#
#       postcode            state property_valuation    country recency  \
# 0     2250.0    New South Wales  8.0                Australia  211
# 1     4305.0    QLD              4.0                Australia  184
# 2     4812.0    QLD              3.0                Australia  236
# 3     4019.0    QLD              8.0                Australia  307
# 4     2519.0    New South Wales  9.0                Australia  48
# ...      ...                ...  ...                      ...  ..
# 1109  4350.0    QLD              2.0                Australia  342
# 1110  2323.0    New South Wales  5.0                Australia  262
# 1111  4551.0    QLD              7.0                Australia  312
# 1112  4820.0    QLD              1.0                Australia  1
# 1113  4217.0    QLD              11.0               Australia  53
#
#      owns_car_flag
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# ...  ..
# 1109  0
# 1110  1
# 1111  1
# 1112  1
# 1113  1
#
# [1114 rows x 27 columns]

# %%
FS = pd.concat([FS, H], ignore_index=True, sort=False)
FMH = FS
df_highvalue_customers = FMH

df_highvalue_customers
# Out:
#       product_id  customer_id transaction_date  online_order order_status  \
# 0     33          1842         2017-06-02       0.0           Approved
# 1     37          595          2017-06-29       1.0           Approved
# 2     44          2570         2017-05-08       1.0           Approved
# 3     45          757          2017-02-26       0.0           Approved
# 4     78          1468         2017-11-12       0.0           Approved
# ...   ..           ...                ...       ...                ...
# 1696  49          650          2017-02-13       1.0           Approved
# 1697  45          2115         2017-06-04       0.0           Approved
# 1698  59          528          2017-10-13       1.0           Approved
# 1699  29          650          2017-08-31       0.0           Approved
# 1700  42          3196         2017-05-29       0.0           Approved
#
#                brand product_line product_class product_size  list_price  ...  \
# 0     Giant Bicycles  Standard     medium        small        1311.44     ...
# 1     OHM Cycles      Standard     low           medium       1793.43     ...
# 2     WeareA2B        Standard     medium        medium       1769.64     ...
# 3     Solex           Standard     medium        medium       441.49      ...
# 4     Giant Bicycles  Standard     medium        large        1765.30     ...
# ...              ...       ...        ...          ...            ...     ...
# 1696  Trek Bicycles   Road         medium        medium       533.51      ...
# 1697  Solex           Standard     medium        medium       441.49      ...
# 1698  Solex           Standard     medium        large        1061.56     ...
# 1699  Norco Bicycles  Road         medium        medium       543.39      ...
# 1700  OHM Cycles      Road         medium        small        1810.00     ...
#
#                job_title job_industry_category  wealth_segment owns_car  \
# 0     Accountant IV       Financial Services    Mass Customer   No
# 1     VP Marketing        Financial Services    Mass Customer   No
# 2     Professor           Financial Services    Mass Customer   Yes
# 3     Environmental Tech  Financial Services    Mass Customer   No
# 4     Financial Advisor   Financial Services    Mass Customer   No
# ...                 ...                  ...              ...   ..
# 1696  Assistant Manager   Health                Mass Customer   No
# 1697  Food Chemist        Health                Mass Customer   Yes
# 1698  Registered Nurse    Health                Mass Customer   No
# 1699  Assistant Manager   Health                Mass Customer   No
# 1700  Engineer IV         Health                Mass Customer   No
#
#       postcode            state property_valuation    country recency  \
# 0     2250.0    New South Wales  8.0                Australia  211
# 1     4305.0    QLD              4.0                Australia  184
# 2     4812.0    QLD              3.0                Australia  236
# 3     4019.0    QLD              8.0                Australia  307
# 4     2519.0    New South Wales  9.0                Australia  48
# ...      ...                ...  ...                      ...  ..
# 1696  2565.0    New South Wales  7.0                Australia  320
# 1697  3143.0    Victoria         4.0                Australia  209
# 1698  2576.0    New South Wales  10.0               Australia  78
# 1699  2565.0    New South Wales  7.0                Australia  121
# 1700  3977.0    Victoria         7.0                Australia  215
#
#      owns_car_flag
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# ...  ..
# 1696  0
# 1697  1
# 1698  0
# 1699  0
# 1700  0
#
# [1701 rows x 27 columns]
